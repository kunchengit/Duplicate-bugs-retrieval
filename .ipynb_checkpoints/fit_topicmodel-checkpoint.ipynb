# %%
# Train topic models using bugs assigned to CPD platform team. The Hierarchical Dirichlet process model is stored in 'hdpmodel.txt' while the 
# Latent Dirichlet allocation model is stored in 'ldamodel.txt'.
import MySQLdb
import pandas
import itertools
import numpy as np
# import bm25fe
import pickle

# %%
conn = MySQLdb.connect(host='10.117.8.41', port=3306, user='root', passwd='vmware', db='bugfeature')
cur = conn.cursor()

sql = '''SELECT bug_id, short_desc, long_desc
FROM bugs_cpdplatform'''

# bugs = pandas.io.sql.read_sql(sql, conn).set_index(['bug_id'])
bugs = pandas.io.sql.read_sql(sql, conn)

# %%
with open('bugset.txt', 'rb') as f:
    bugset = pickle.load(f)
    
criterion = bugs['bug_id'].map(lambda x: x in bugset)
bugs_train = bugs[criterion]
n = bugs_train.shape[0]

texts = list((bugs_train['short_desc'] +' '+ bugs_train['long_desc']).map(lambda x: x.split()))

# %%
# with open('train100.txt', 'rb') as f:
#    train = pickle.load(f)

# bugset = []
# for item in train:
#     bugset.append(item['query'])
#     bugset.append(item['rel'])
#     bugset += item['irrel']

# bugset = set(bugset)

# criterion = bugs['bug_id'].map(lambda x: x in bugset)
# bugs_train = bugs[criterion]
# n = bugs_train.shape[0]
# texts = list((bugs_train['short_desc'] +' '+ bugs_train['long_desc']).map(lambda x: x.split()))

# %%
# print n
# print len(texts)
# print len(bugset)
# print train
# print bugs_filtered.shape
# print criterion
# print bugset
# print bugs.shape
# print type(criterion1)

# %%
from gensim import corpora

dictionary = corpora.Dictionary(list(bugs_train['long_desc'].map(lambda x: x.split())))
dictionary.filter_extremes(no_below = 10, no_above = 0.9, keep_n = 100000)
dictionary.add_documents(list(bugs_train['short_desc'].map(lambda x: x.split())))

dictionary.save_as_text('dictionary.txt')

corpus = [dictionary.doc2bow(text) for text in texts]

# %%
from gensim.models import hdpmodel
hdp = hdpmodel.HdpModel(corpus, id2word=dictionary)
hdp.save('hdpmodel.txt')
# Out:
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!
# WARNING:gensim.models.hdpmodel:likelihood is decreasing!

# %%
from gensim.models import ldamulticore
lda = ldamulticore.LdaMulticore(corpus, id2word=dictionary, iterations=10000)
lda.save('ldamodel.txt')
# Out:
# WARNING:gensim.models.ldamulticore:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy

# %%
print dictionary.dfs
print dictionary.dfs.values()
# Out:
# {0: 30, 1: 78, 2: 82, 3: 33, 4: 16, 5: 11, 6: 87, 7: 179, 8: 247, 9: 15, 10: 54, 11: 338, 12: 14, 13: 12, 14: 14, 15: 20, 16: 10, 17: 18, 18: 53, 19: 51, 20: 43, 21: 26, 22: 22, 23: 12, 24: 630, 25: 138, 26: 10, 27: 55, 28: 24, 29: 12, 30: 14, 31: 171, 32: 17, 33: 24, 34: 52, 35: 18, 36: 13, 37: 589, 38: 33, 39: 16, 40: 17, 41: 149, 42: 40, 43: 23, 44: 48, 45: 13, 46: 28, 47: 15, 48: 24, 49: 23, 50: 20, 51: 20, 52: 47, 53: 12, 54: 23, 55: 12, 56: 21, 57: 204, 58: 927, 59: 36, 60: 10, 61: 64, 62: 28, 63: 1018, 64: 46, 65: 1460, 66: 17, 67: 26, 68: 13, 69: 13, 70: 18, 71: 39, 72: 41, 73: 1104, 74: 19, 75: 544, 76: 17, 77: 13, 78: 34, 79: 10, 80: 27, 81: 18, 82: 14, 83: 37, 84: 22, 85: 13, 86: 45, 87: 43, 88: 16, 89: 32, 90: 10, 91: 48, 92: 38, 93: 976, 94: 10, 95: 34, 96: 73, 97: 12, 98: 221, 99: 10, 100: 27, 101: 350, 102: 274, 103: 13, 104: 107, 105: 40, 106: 138, 107: 16, 108: 17, 109: 22, 110: 131, 111: 16, 112: 568, 113: 16, 114: 10, 115: 13, 116: 10, 117: 133, 118: 10, 119: 15, 120: 2177, 121: 10, 122: 55, 123: 10, 124: 126, 125: 82, 126: 13, 127: 2467, 128: 10, 129: 27, 130: 68, 131: 78, 132: 10, 133: 37, 134: 17, 135: 24, 136: 165, 137: 13, 138: 66, 139: 217, 140: 320, 141: 613, 142: 30, 143: 28, 144: 310, 145: 12, 146: 12, 147: 36, 148: 22, 149: 35, 150: 13, 151: 26, 152: 19, 153: 41, 154: 24, 155: 177, 156: 12, 157: 1003, 158: 11, 159: 18, 160: 23, 161: 174, 162: 32, 163: 10, 164: 21, 165: 18, 166: 11, 167: 45, 168: 11, 169: 372, 170: 17, 171: 310, 172: 11, 173: 11, 174: 12, 175: 60, 176: 92, 177: 86, 178: 21, 179: 643, 180: 22, 181: 238, 182: 35, 183: 29, 184: 297, 185: 20, 186: 12, 187: 25, 188: 71, 189: 47, 190: 15, 191: 46, 192: 11, 193: 14, 194: 17, 195: 411, 196: 16, 197: 11, 198: 140, 199: 110, 200: 11, 201: 19, 202: 21, 203: 26, 204: 29, 205: 18, 206: 20, 207: 73, 208: 11, 209: 11, 210: 14, 211: 44, 212: 43, 213: 10, 214: 70, 215: 11, 216: 17, 217: 17, 218: 49, 219: 18, 220: 300, 221: 11, 222: 29, 223: 27, 224: 12, 225: 25, 226: 19, 227: 12, 228: 13, 229: 11, 230: 31, 231: 62, 232: 88, 233: 151, 234: 10, 235: 56, 236: 10, 237: 46, 238: 16, 239: 117, 240: 17, 241: 14, 242: 13, 243: 282, 244: 11, 245: 10, 246: 39, 247: 10, 248: 24, 249: 13, 250: 71, 251: 980, 252: 20, 253: 12, 254: 24, 255: 48, 256: 320, 257: 62, 258: 87, 259: 12, 260: 31, 261: 497, 262: 64, 263: 438, 264: 30, 265: 44, 266: 53, 267: 39, 268: 185, 269: 25, 270: 18, 271: 15, 272: 158, 273: 11, 274: 17, 275: 23, 276: 86, 277: 31, 278: 12, 279: 61, 280: 26, 281: 44, 282: 20, 283: 10, 284: 16, 285: 15, 286: 10, 287: 220, 288: 11, 289: 359, 290: 12, 291: 12, 292: 12, 293: 26, 294: 17, 295: 12, 296: 36, 297: 115, 298: 150, 299: 957, 300: 392, 301: 53, 302: 206, 303: 25, 304: 11, 305: 14, 306: 113, 307: 11, 308: 13, 309: 544, 310: 38, 311: 22, 312: 19, 313: 21, 314: 13, 315: 29, 316: 11, 317: 13, 318: 10, 319: 101, 320: 11, 321: 413, 322: 33, 323: 13, 324: 14, 325: 16, 326: 24, 327: 11, 328: 27, 329: 22, 330: 197, 331: 14, 332: 27, 333: 13, 334: 29, 335: 19, 336: 277, 337: 68, 338: 35, 339: 11, 340: 47, 341: 24, 342: 58, 343: 11, 344: 24, 345: 14, 346: 10, 347: 23, 348: 29, 349: 10, 350: 10, 351: 12, 352: 12, 353: 12, 354: 84, 355: 11, 356: 1011, 357: 16, 358: 68, 359: 196, 360: 46, 361: 33, 362: 45, 363: 19, 364: 16, 365: 22, 366: 131, 367: 14, 368: 13, 369: 84, 370: 14, 371: 63, 372: 16, 373: 20, 374: 59, 375: 44, 376: 458, 377: 52, 378: 63, 379: 41, 380: 11, 381: 740, 382: 588, 383: 30, 384: 14, 385: 298, 386: 13, 387: 19, 388: 1089, 389: 56, 390: 195, 391: 10, 392: 13, 393: 301, 394: 10, 395: 44, 396: 13, 397: 11, 398: 17, 399: 10, 400: 11, 401: 123, 402: 38, 403: 21, 404: 24, 405: 17, 406: 29, 407: 17, 408: 10, 409: 13, 410: 124, 411: 42, 412: 1659, 413: 108, 414: 1519, 415: 48, 416: 1024, 417: 24, 418: 11, 419: 10, 420: 13, 421: 20, 422: 10, 423: 73, 424: 26, 425: 35, 426: 11, 427: 11, 428: 26, 429: 10, 430: 905, 431: 11, 432: 33, 433: 33, 434: 1299, 435: 16, 436: 33, 437: 196, 438: 921, 439: 20, 440: 17, 441: 11, 442: 12, 443: 61, 444: 51, 445: 77 ...
# [30, 78, 82, 33, 16, 11, 87, 179, 247, 15, 54, 338, 14, 12, 14, 20, 10, 18, 53, 51, 43, 26, 22, 12, 630, 138, 10, 55, 24, 12, 14, 171, 17, 24, 52, 18, 13, 589, 33, 16, 17, 149, 40, 23, 48, 13, 28, 15, 24, 23, 20, 20, 47, 12, 23, 12, 21, 204, 927, 36, 10, 64, 28, 1018, 46, 1460, 17, 26, 13, 13, 18, 39, 41, 1104, 19, 544, 17, 13, 34, 10, 27, 18, 14, 37, 22, 13, 45, 43, 16, 32, 10, 48, 38, 976, 10, 34, 73, 12, 221, 10, 27, 350, 274, 13, 107, 40, 138, 16, 17, 22, 131, 16, 568, 16, 10, 13, 10, 133, 10, 15, 2177, 10, 55, 10, 126, 82, 13, 2467, 10, 27, 68, 78, 10, 37, 17, 24, 165, 13, 66, 217, 320, 613, 30, 28, 310, 12, 12, 36, 22, 35, 13, 26, 19, 41, 24, 177, 12, 1003, 11, 18, 23, 174, 32, 10, 21, 18, 11, 45, 11, 372, 17, 310, 11, 11, 12, 60, 92, 86, 21, 643, 22, 238, 35, 29, 297, 20, 12, 25, 71, 47, 15, 46, 11, 14, 17, 411, 16, 11, 140, 110, 11, 19, 21, 26, 29, 18, 20, 73, 11, 11, 14, 44, 43, 10, 70, 11, 17, 17, 49, 18, 300, 11, 29, 27, 12, 25, 19, 12, 13, 11, 31, 62, 88, 151, 10, 56, 10, 46, 16, 117, 17, 14, 13, 282, 11, 10, 39, 10, 24, 13, 71, 980, 20, 12, 24, 48, 320, 62, 87, 12, 31, 497, 64, 438, 30, 44, 53, 39, 185, 25, 18, 15, 158, 11, 17, 23, 86, 31, 12, 61, 26, 44, 20, 10, 16, 15, 10, 220, 11, 359, 12, 12, 12, 26, 17, 12, 36, 115, 150, 957, 392, 53, 206, 25, 11, 14, 113, 11, 13, 544, 38, 22, 19, 21, 13, 29, 11, 13, 10, 101, 11, 413, 33, 13, 14, 16, 24, 11, 27, 22, 197, 14, 27, 13, 29, 19, 277, 68, 35, 11, 47, 24, 58, 11, 24, 14, 10, 23, 29, 10, 10, 12, 12, 12, 84, 11, 1011, 16, 68, 196, 46, 33, 45, 19, 16, 22, 131, 14, 13, 84, 14, 63, 16, 20, 59, 44, 458, 52, 63, 41, 11, 740, 588, 30, 14, 298, 13, 19, 1089, 56, 195, 10, 13, 301, 10, 44, 13, 11, 17, 10, 11, 123, 38, 21, 24, 17, 29, 17, 10, 13, 124, 42, 1659, 108, 1519, 48, 1024, 24, 11, 10, 13, 20, 10, 73, 26, 35, 11, 11, 26, 10, 905, 11, 33, 33, 1299, 16, 33, 196, 921, 20, 17, 11, 12, 61, 51, 77, 10, 99, 2321, 31, 16, 364, 30, 956, 19, 1629, 251, 13, 12, 65, 11, 185, 42, 17, 16, 33, 11, 11, 72, 25, 277, 256, 28, 507, 10, 105, 37, 24, 27, 16, 31, 109, 10, 451, 22, 446, 14, 12, 68, 897, 21, 344, 33, 10, 36, 45, 173, 11, 21, 26, 14, 10, 1209, 19, 17, 10, 17, 242, 694, 15, 257, 88, 30, 35, 115, 14, 12, 15, 25, 54, 15, 20, 229, 39, 2056, 17, 44, 37, 15, 196, 11, 21, 13, 111, 37, 85, 50, 12, 27, 76, 13, 21, 23, 38, 56, 126, 16, 116, 59, 84, 11, 41, 23, 11, 22, 36, 169, 11, 20, 10, 11, 11, 16, 17, 28, 12, 78, 16, 14, 36, 969, 105, 19, 88, 1185, 12, 123, 70, 14, 50, 516, 34, 1408, 22, 14, 30, 13, 10, 29, 10, 38, 28, 13, 26, 12, 327, 13, 31, 46, 147, 13, 23, 33, 17, 11, 10, 14, 13, 72, 16, 27, 238, 11, 308, 12, 16, 286, 10, 56, 36, 21, 17, 16, 13, 50, 13, 23, 33, 15, 11, 17, 19, 330, 10, 12, 13, 14, 18, 15, 959, 13, 13, 346, 2131, 339, 14, 218, 351, 1950, 15, 24, 12, 19, 27, 12, 35, 265, 29, 195, 34, 272, 14, 72, 14, 14, 15, 16, 41, 109, 10, 102, 27, 236, 679, 55, 25, 385, 10, 35, 32, 11, 16, 23, 10, 2300, 1658, 14, 150, 425, 13, 23, 59, 297, 10, 21, 46, 59, 10, 13, 260, 29, 16, 17, 20, 50, 153, 21, 61, 450, 27, 34, 21, 22, 27, 10, 23, 11, 1601, 11, 11, 26, 15, 71, 15, 107, 54, 45, 12, 11, 23, 52, 16, 11, 472, 10, 11, 15, 13, 14, 62, 42, 136, 15, 601, 12, 14, 16, 10, 19, 10, 35, 78, 15, 112, 38, 27, 43, 26, 374, 26, 30, 33, 15, 49, 13, 85, 14, 16, 29, 29, 43, 17, 14, 12, 58, 12, 11, 27, 69, 1053, 13, 17, 16, 25, 18, 22, 28, 17, 164, 39, 16, 30, 18, 13, 49, 22, 11, 25, 21, 12, 12, 150, 180, 13, 19, 11, 12, 215, 58, 90, 13, 41, 47, 529, 27, 25, 54, 35, 306, 388, 203, 10, 190, 86, 10, 2254, 16, 1228, 14, 16, 19, 12, 28, 17, 32, 11, 27, 15, 10, 216, 27, 19, 372, 55, 16, 17, 1282, 10, 992, 12, 10, 147, 72, 17, 21, 77, 632, 16, 297, 20, 18, 10, 14, 39, 11, 64, 32, 53, 545, 377, 38, 13, 440, 110, 92, 17, 21, 77, 23, 21, 189, 36, 28, 25, 1390, 12, 27, 20, 73, 20, 46, 269, 41, 1043, 363, 13, 33, 13, 12, 81, 159, 16, 25, 23, 12, 41, 10, 15, 79, 33, 27, 29, 22, 17, 25, 15, 26, 15, 22, 124, 10, 62, 78, 16, 10, 32, 26, 12, 15, 41, 534, 10, 53, 75, 19, 29, 16, 17, 10, 29, 22, 335, 17, 26, 58, 72, ...
