# %%
# Some test on how to conduct pre-processing (test some NLP technics)

import MySQLdb
import pandas
import re
import itertools
import nltk
from bs4 import BeautifulSoup

# %%
def rm_cite(raw_text):
    lst = []
    iscite = False
    lines = raw_text.splitlines()
    for idx,line in enumerate(lines):
        if line.startswith("(In reply to comment"):
            iscite = True
            lst.append(idx)
        elif line.startswith(">"):
            if iscite == True:
                lst.append(idx)
        else:
            iscite = False
        
    return '\n'.join([item[1] for item in filter(lambda x: x[0] not in lst, enumerate(lines))])

# %%
from nltk.stem.snowball import SnowballStemmer
from bs4 import BeautifulSoup

def preprocess_strict( raw_description, output):
    # Function to convert a raw bug description to a list of words or a cleared string, it's "strict" in the sense that it removes all non-letters 
    # Remove markers
    # text = BeautifulSoup(raw_description).get_text() 
    
    # Remove cites
    description = rm_cite(raw_description)
    
    # Remove urls
    text = re.sub("((mailto\:|(news|(ht|f)tp(s?))\://){1}\S+)", " ", description)
    
    # Remove non-letters        
    # letters_only = re.sub("[^a-zA-Z_/\-\.]", " ", description_text)
    letters_only = re.sub("[^a-zA-Z\.]", " ", text)
    letters_only = re.sub("\.(?!((c|h|cpp|py)\s+$))", " ", letters_only)
    
    # Convert to lower case, tokenize
    words = [word for sent in nltk.sent_tokenize(letters_only.lower()) for word in nltk.word_tokenize(sent)]
    
    # Remove stop words
    stopwords = set(nltk.corpus.stopwords.words('english'))
    meaningful_words = [w for w in words if not w in stopwords]
    
    # Stemming
    snowball = SnowballStemmer("english")
    stems = [snowball.stem(w) for w in meaningful_words]
    
    if output == "list":
        return stems
    else:
        return " ".join(stems)

# %%
def tokenize_and_stem( raw_description ):
    text = BeautifulSoup(raw_description).get_text()
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    
    stopwords = set(nltk.corpus.stopwords.words('english'))
    meaningful_tokens = [token for token in filtered_tokens if not token in stopwords]
    snowball = SnowballStemmer("english")
    stems = [snowball.stem(t) for t in filtered_tokens]
    return stems

# %%
def tokenizestem_to_string( raw_description ):
    
    return " ".join(tokenize_and_stem(raw_description))

# %%
conn_data = MySQLdb.connect(host='10.117.8.41', port=3306, user='root', passwd='vmware', db='bugdata')
cur_data =conn_data.cursor()

sql_ld = '''SELECT bug_id, thetext
FROM longdescs
WHERE bug_id = 943195'''
    
df = pandas.io.sql.read_sql(sql_ld, conn_data)

for idx, row in df.iterrows():
    print idx,'\n', "*****", '\n', row['thetext']
# Out:
# 0
# *****
# SR ID: SR  12224870309
# Customer: IBM / GMT (+1 DST) / cool
# Product Version/Build Numbers: VMware Tools 9.0.0 build-782409
# Regressed from previous release?: NA
# Frequency: repruducible
# Time of Failure/Last Occurrence: NA
# Time Skew between various machines?: NA
# Recent Changes to the Environment? Upgrade to 5.1 GA
# Date Opened in Support: 2012-09-24
# Guest: Ubuntu 10.04 (2.6.32-24-generic #39-Ubuntu SMP)
# Server IP/Hostname: NA
# Problem description: Snapshot task for a Linux VM fails with
#
# "An error occurred while quiescing the virtual machine. See the virtual machine's event log for details."
#
# According to the customer, this only happens for 5.1, not for an 5.0 or 4.x Tools (which makes sense, because as far as I can see, the "new" freeze is only in the most recent Tools),
#
# Impact: IBM is concerned that their customers will have issues with their backup software, which by default sets the quiesce flag.
# Which VMs in questions have problems: .ova attached to the PR
# Guest OS VMX File Path: .ova attached to the PR
# Logs/files location: repro details below / .ova attached to the PR
#
# Installed Tools from the linux.iso and followed the default selections (e.g. no on vmsync)
#
# created /etc/vmware/tools.conf with:
#
# [logging]
# log = true
# vmsvc.level = debug
# vmsvc.handler = vmx
# vmbackup.level = debug
# vmbackup.handler = vmx
#
# customers VM: (2.6.32-24-generic #39-Ubuntu SMP) when a user is logged on (tty1)
#
# 2012-10-11T11:13:11.683Z| vcpu-0| I120: ToolsBackup: changing quiesce state: IDLE -> STARTED
# 2012-10-11T11:13:12.683Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupAsyncCallback
# 2012-10-11T11:13:12.683Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] VmBackupAsyncCallback: checking VmBackupOnFreeze
# 2012-10-11T11:13:12.683Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] Async request 'VmBackupOnFreeze' completed
# 2012-10-11T11:13:12.683Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupEnableSync
# 2012-10-11T11:13:12.684Z| vcpu-0| I120: Guest: [    info] [vmsvc:guestinfo] Poll loop disabled.
# 2012-10-11T11:13:12.684Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupSyncDriverStart
# 2012-10-11T11:13:12.684Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmsvc] SyncDriver: Freezing using Linux ioctls...
# 2012-10-11T11:13:30.356Z| vmx| I120: GuestRpcSendTimedOut: message to toolbox timed out.
#
#
# my VM: (2.6.32-21-generic #32-Ubuntu SMP) when a user is logged on (tty1)
#
# 2012-10-11T10:50:25.347Z| vcpu-0| I120: ToolsBackup: changing quiesce state: IDLE -> STARTED
# 2012-10-11T10:50:26.347Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupAsyncCallback
# 2012-10-11T10:50:26.347Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] VmBackupAsyncCallback: checking VmBackupOnFreeze
# 2012-10-11T10:50:26.347Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] Async request 'VmBackupOnFreeze' completed
# 2012-10-11T10:50:26.347Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupEnableSync
# 2012-10-11T10:50:26.347Z| vcpu-0| I120: Guest: [    info] [vmsvc:guestinfo] Poll loop disabled.
# 2012-10-11T10:50:26.347Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupSyncDriverStart
# 2012-10-11T10:50:26.348Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmsvc] SyncDriver: Freezing using Linux ioctls...
# 2012-10-11T10:50:26.381Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmsvc] SyncDriver: successfully froze '/'.
#
# Sometimes, the customers VM "hangs" after a failed snapshot, errors similar to this can be seen on another tty:
#
# INFO: task rsyslogd:692 blocked for more than 120 seconds.
# "echo 0 > /proc/sys/kernel/hung_task_timeout_secs" disables this message.
#
# INFO: task vmtoolsd:1078 blocked for more than 120 seconds.
# "echo 0 > /proc/sys/kernel/hung_task_timeout_secs" disables this message.
#
# INFO: task flush-8:0:1116 blocked for more than 120 seconds.
# "echo 0 > /proc/sys/kernel/hung_task_timeout_secs" disables this message.
#
#
#
# https://opengrok.eng.vmware.com/source/xref/vsphere5x.perforce.1666/bora-vmsoft/lib/syncDriver/syncDriverLinux.c#95
#
# /*
#  *******************************************************************************
#  * LinuxDriver_Freeze --                                                  */ /**
#  *
#  * Tries to freeze the filesystems using the Linux kernel's FIFREEZE ioctl.
#  *
#  * If the first attempt at using the ioctl fails, assume that it doesn't exist
#  * and return SD_UNAVAILABLE, so that other means of freezing are tried.
#  *
#  * @param[in]  paths    Paths to freeze (colon-separated).
#  * @param[out] handle   Handle to use for thawing.
#  *
#  * @return A SyncDriverErr.
#  *
#  *******************************************************************************
#  */
#
# SyncDriverErr
# LinuxDriver_Freeze(const char *paths,
#                    SyncDriverHandle *handle)
# {
#    char *path;
#    int fd;
#    size_t count = 0;
#    unsigned int index = 0;
#    Bool first = TRUE;
#    DynBuf fds;
#    LinuxDriver *sync = NULL;
#    SyncDriverErr err = SD_SUCCESS;
#
#    DynBuf_Init(&fds);
#
#    Debug(LGPFX "Freezing using Linux ioctls...\n");
#
#    sync = calloc(1, sizeof *sync);
#    if (sync == NULL) {
#       return SD_ERROR;
#    }
#
#    sync->driver.thaw = LinuxFiThaw;
#    sync->driver.close = LinuxFiClose;
#
#
# Here an excerpt from my setup with samples_on:
#
# 2012-10-11T12:16:43.607Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupStart
# 2012-10-11T12:16:43.607Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] Using quiesceApps = 1, quiesceFS = 1, allowHWProvider = 1,execScripts = 1, scriptArg = , timeout = 0
# 2012-10-11T12:16:43.607Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] Quiescing volumes: (null)
# 2012-10-11T12:16:43.607Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackup_SendEvent
# 2012-10-11T12:16:43.608Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupStartScripts
# 2012-10-11T12:16:43.608Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] Trying to run scripts from /etc/vmware-tools/backupScripts.d
# 2012-10-11T12:16:43.608Z| vcpu-0| I120: ToolsBackup: changing quiesce state: IDLE -> STARTED
# 2012-10-11T12:16:44.270Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:44.359Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmtoolsd] Setting option 'broadcastIP' to '1'.
# 2012-10-11T12:16:44.497Z| vcpu-0| I120: HBACommon: First write on scsi0:0.fileName='/vmfs/volumes/50754a72-c3572cc0-2f5e-002522e84d6a/UbuntuQuiescedSnapshotErrorCustomerVM-12224870309/UbuntuQuiescedSnapshotErrorCustomerVM-12224870309.vmdk'
# 2012-10-11T12:16:44.497Z| vcpu-0| I120: DDB: "longContentID" = "44e94886a09462321d590fdb367ce74e" (was "74b6dd73b99ed05d2138b442b84cc479")
# 2012-10-11T12:16:44.532Z| vcpu-0| I120: DISKLIB-CHAIN : DiskChainUpdateContentID: old=0xb84cc479, new=0x367ce74e (44e94886a09462321d590fdb367ce74e)
# 2012-10-11T12:16:44.607Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupAsyncCallback
# 2012-10-11T12:16:44.607Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] VmBackupAsyncCallback: checking VmBackupOnFreeze
# 2012-10-11T12:16:44.607Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] Async request 'VmBackupOnFreeze' completed
# 2012-10-11T12:16:44.608Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupEnableSync
# 2012-10-11T12:16:44.608Z| vcpu-0| I120: Guest: [    info] [vmsvc:guestinfo] Poll loop disabled.
# 2012-10-11T12:16:44.608Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupSyncDriverStart
# 2012-10-11T12:16:44.608Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmsvc] SyncDriver: Freezing using Linux ioctls...
# 2012-10-11T12:16:45.283Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:46.299Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:47.315Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:48.331Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:49.351Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:49.791Z| vmx| I120: GuestRpcSendTimedOut: message to toolbox timed out.
# 2012-10-11T12:16:50.369Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:51.387Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:52.405Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:53.423Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:54.441Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:55.459Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:56.473Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:57.493Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:58.511Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:59.525Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:17:00.543Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:17:01.559Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:17:02.579Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:17:03.595Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:17:04.611Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:17:04.793Z| vmx| I120: GuestRpcSendTimedOut: message to toolbox timed out.
# 2012-10-11T12:17:04.793Z| vmx| I120: GuestRpc: app toolbox's second ping timeout; assuming app is down
# 2012-10-11T12:17:04.793Z| vmx| I120: ToolsBackup: changing quiesce state: STARTED -> DONE
# 2012-10-11T12:17:04.793Z| vmx| I120: SnapshotVMXTakeSnapshotComplete: done with snapshot 'sdfdaf': 0
# 2012-10-11T12:17:04.793Z| vmx| I120: SnapshotVMXTakeSnapshotComplete: Snapshot 0 failed: Failed to quiesce the virtual machine (40).
#
#
# vmware-5.log and vmss file (suspended the VM after the snapshot failed) are attached as well, just in case.
#
# UbuntuQuiescedSnapshotErrorCustomerVM-12224870309-de861639.vmss.gz - md5sum 23ffd0d31c310b08cbbbfd31125a0720
#
#
# Steps to reproduce / what led to this:
# ======================================
# Issue Reproducible? Y - with the customers VM
# GSS Repro Attempt Status: Y, could not reproduce on Ubuntu 12.04 / 10.04, although with a slightly different version (2.6.32-21-generic #32-Ubuntu SMP)
#
# Find details for my whitebox below:
#
# vCenter: 10.26.165.145
# User: administrator
# Password: VMware123
#
# The VMs display name is: UbuntuQuiescedSnapshotErrorCustomerVM-12224870309
# It can be reached via SSH on: 10.26.165.227
# User: root
# Password: quiesce
#
# Note that sometimes taking quiesced snapshots just works, in that case just reboot the VM and log on to a tty, it seems that it fails more often when a user is logged on (over the MKS). It might have been coincidences though.
#
# Troubleshooting done or workarounds applied:
# ============================================
# BY TS: tried to reproduce the issue, couldn't without the customers VM though
# BY Customer:  only workaround is to not select quiece when snapshotting
# Research conducted: found no matching PRs
# Customer Expectations/Next Steps: fix if VMware issue (the customer is aware that this might be a Linux kernel bug), explanation if there is a way to ignore the quiesce from the VMs point of view / not use the new freeze feature
# 1
# *****
# (vbondzio)-(jobs:0)-(/bugs/files/0/0/9/4/3/1/9/5/12224870309)
# (...)
# -rwxrwxrwx 1 vbondzio support 382899712 2012-10-11 01:20 IBM_Test_new.ova
# -rwxrwxrwx 1 vbondzio support  26764816 2012-10-11 05:20 UbuntuQuiescedSnapshotErrorCustomerVM-12224870309-de861639.vmss.gz
# -rwxrwxrwx 1 vbondzio support    365045 2012-10-11 05:19 vmware-5.log
# 2
# *****
# Sankar, time permitting, could you also take a look?
# 3
# *****
# (In reply to comment #0)
# > Which VMs in questions have problems: .ova attached to the PR
# > Guest OS VMX File Path: .ova attached to the PR
#
# What are the login credentials (root/???) for the attached .ova VM?
# 4
# *****
# Hi Sankar,
#
# sorry for not making that clear, the repro VM was deployed from the .ova and has the same root password:
#
# User: root
# Password: quiesce
#
# Cheers
#
# Valentin
# 5
# *****
# (In reply to comment #7)
# > sorry for not making that clear, the repro VM was deployed from the .ova and has the same root password:
#
# Thanks for providing the login credentials. I deployed the .ova template and reproduced the issue. For now, there is a workaround. Add the following two lines in the tools.conf file.
#
# [vmbackup]
# enableSyncDriver = false
#
# This will disable the sync driver and quiesce operation uses the 'sync(2)' approach. (Check https://opengrok.eng.vmware.com/source/xref/vmkernel-main.perforce.1666/bora-vmsoft/services/plugins/vmbackup/nullProvider.c#36)
# 6
# *****
# (In reply to comment #8)
# > Thanks for providing the login credentials. I deployed the .ova template and reproduced the issue. For now, there is a workaround. Add the following two lines in the tools.conf file.
#
# I would say this is a bug in the Linux kernel. I googled for 'blocked for more than 120 seconds' message and noticed many community/forum posts talking about this error for Ubuntu guests. 'VMware Tools' execute ioctl for FIFREEZE and waits. 'Tools' doesn't control the time taken for the task. How about asking the customer to upgrade their Ubuntu VM to the latest kernel (the attached .ova has the linux kernel 2.6.32) and see if it solves the issue.
# 7
# *****
# Hi Sankar,
#
# I should have probably looked around a bit more but I thought you could easily give me stacks of blocking threads that go through fsfreeze to have a little bit more to google for (I'm not into Linux at all and don't have GDB set up). All things considered, I think: http://patchwork.ozlabs.org/patch/92507/ is a pretty good candidate. Is there a quick way for you to confirm this?
#
# In any case, I'll document it as a possible Linux bug.
#
# Cheers
#
# Valentin
# 8
# *****
# (In reply to comment #10)
# > I should have probably looked around a bit more but I thought you could easily give me stacks of blocking threads that go through fsfreeze to have a little bit more to google for (I'm not into Linux at all and don't have GDB set up). All things considered, I think: http://patchwork.ozlabs.org/patch/92507/ is a pretty good candidate. Is there a quick way for you to confirm this?
#
# Hmm. Following is the output of strace for 'vmtoolsd' when the 'quiesce operation' was triggered.
#
# read(25, "/dev/sda1 / ext4 rw,errors=remou"..., 4096) = 559
# read(25, "", 4096)                      = 0
# close(25)                               = 0
# munmap(0xb6654000, 4096)                = 0
# gettimeofday({1351212992, 500696}, NULL) = 0
# stat64("/etc/localtime", {st_mode=S_IFREG|0644, st_size=2309, ...}) = 0
# write(5, "[Oct 26 02:56:32.500] [   debug]"..., 84) = 84
# open("/", O_RDONLY|O_LARGEFILE)         = 25
# ioctl(25, 0xc0045877
#
# It just stuck there. ioctl is blocking. I don't have any info about the kernel threads. I downloaded the kernel source from http://www.kernel.org/pub/linux/kernel/v2.6/longterm/v2.6.32/linux-2.6.32.60.tar.bz2 and tried building that. But couldn't build it completely with the VM that was provided. Will try again.
# 9
# *****
# I think I hust hit this issue on SR# 12237488110. Very similar failure, except we experienced no hang up or freezing issues, just the queisced snapshots failed. The Guests in my case were RHEL 5 and RHEL 6.
#
# Customer had just upgraded to ESXi 5.1 and upgrade Tools via OSP. The issue did not occur until they were using 5.1 Tools. The workaround listed in Update #8 corrected the issue, and customer was happy with the solution.
# 10
# *****
# Wrote KB# 2038606 to help track this issue.
# 11
# *****
# It would be interesting to see the the state of the processes in the system (echo t > /proc/sysrq-trigger and echo w > /proc/sysrq-trigger).
# 12
# *****
# *** Child bug 959936 has been spawned from bug 943195. ***
# 13
# *****
# Start RCCA process.
# 14
# *****
# The root cause is that:
# The old vmware tools sent "ioctl(handle, SYNC_IOC_THAW)" to vmsync driver to do the quiesce snapshot, and the vmsync driver implement the process of SYNC_IOC_THAW ioctl.
# Since Linux kernel 2.6.32, the kernel itself started to support FIFREESE/FITHAW ioctl, and no need to use our vmsync driver.
# Unfortunately, the customer's ubuntu10.04(2.6.32-24) has bugs about FIFREESE/FITHAW ioctl which will cause the failure of ioctl and may hang the system.
#
# As a result, the customer could ether updating linux kernel or using old vmware tools to avoid this issue.
#
# I update customer's VM kernel from 2.6.32-24 to 2.6.35-22 and the quiesce snapshot could success.
# The ova is uploaded IBM_Test_with_new_kernel.ova. It includes 2 snapshot: one is using the customer's old kernel and the other is using a newer linux kernel.
# 15
# *****
# Due to the attachment size limitation, I can't upload the ova file. If somebody need it, please let me know.
# 16
# *****
# The ova is uploaded.
# 17
# *****
# Hi,
# Can we have a customer friendly version of this RCA that we can add to the cause section of KB 2038606?
#
# I was thinking something like:
# "Cause:
# Since the release of Linux kernel 2.6.32, Linux now supports quiescing natively, Unfortunately there was a bug in the 2.6.32-24 which prevented this feature from working correctly."
#
# Resolution:
# This issue is resolved by updating the kernel of your linux guest to 2.6.35-22 or higher.
#
# To workaround the issue:....."
#
# Thoughts?
# (In reply to comment #23)
# > The root cause is that:
# > The old vmware tools sent "ioctl(handle, SYNC_IOC_THAW)" to vmsync driver to do the quiesce snapshot, and the vmsync driver implement the process of SYNC_IOC_THAW ioctl.
# > Since Linux kernel 2.6.32, the kernel itself started to support FIFREESE/FITHAW ioctl, and no need to use our vmsync driver.
# > Unfortunately, the customer's ubuntu10.04(2.6.32-24) has bugs about FIFREESE/FITHAW ioctl which will cause the failure of ioctl and may hang the system.
# >
# > As a result, the customer could ether updating linux kernel or using old vmware tools to avoid this issue.
# >
# > I update customer's VM kernel from 2.6.32-24 to 2.6.35-22 and the quiesce snapshot could success.
# > The ova is uploaded IBM_Test_with_new_kernel.ova. It includes 2 snapshot: one is using the customer's old kernel and the other is using a newer linux kernel.
# >
# >
# 18
# *****
# It's ok for me to add a KB for this issue.
#
# (In reply to comment #30)
# > Hi,
# > Can we have a customer friendly version of this RCA that we can add to the cause section of KB 2038606?
# >
# > I was thinking something like:
# > "Cause:
# > Since the release of Linux kernel 2.6.32, Linux now supports quiescing natively, Unfortunately there was a bug in the 2.6.32-24 which prevented this feature from working correctly."
# >
# > Resolution:
# > This issue is resolved by updating the kernel of your linux guest to 2.6.35-22 or higher.
# >
# > To workaround the issue:....."
# >
# > Thoughts?
# > (In reply to comment #23)
# >
# > The root cause is that:
# > The old vmware tools sent "ioctl(handle, SYNC_IOC_THAW)" to vmsync driver to do the quiesce snapshot, and the vmsync driver implement the process of SYNC_IOC_THAW ioctl.
# > Since Linux kernel 2.6.32, the kernel itself started to support FIFREESE/FITHAW ioctl, and no need to use our vmsync driver.
# > Unfortunately, the customer's ubuntu10.04(2.6.32-24) has bugs about FIFREESE/FITHAW ioctl which will cause the failure of ioctl and may hang the system.
# >
# > As a result, the customer could ether updating linux kernel or using old vmware tools to avoid this issue.
# >
# > I update customer's VM kernel from 2.6.32-24 to 2.6.35-22 and the quiesce snapshot could success.
# > The ova is uploaded IBM_Test_with_new_kernel.ova. It includes 2 snapshot: one is using the customer's old kernel and the other is using a newer linux kernel.
# >
# >
# >
# >
# 19
# *****
# (In reply to comment #33)
# > It's ok for me to add a KB for this issue.
# >
# > (In reply to comment #30)
# >
# > Hi,
# > Can we have a customer friendly version of this RCA that we can add to the cause section of KB 2038606?
# >
# > I was thinking something like:
# > "Cause:
# > Since the release of Linux kernel 2.6.32, Linux now supports quiescing natively, Unfortunately there was a bug in the 2.6.32-24 which prevented this feature from working correctly."
# >
# > Resolution:
# > This issue is resolved by updating the kernel of your linux guest to 2.6.35-22 or higher.
# >
# > To workaround the issue:....."
# >
# > Thoughts?
# > (In reply to comment #23)
# >
# > The root cause is that:
# > The old vmware tools sent "ioctl(handle, SYNC_IOC_THAW)" to vmsync driver to do the quiesce snapshot, and the vmsync driver implement the process of SYNC_IOC_THAW ioctl.
# > Since Linux kernel 2.6.32, the kernel itself started to support FIFREESE/FITHAW ioctl, and no need to use our vmsync driver.
# > Unfortunately, the customer's ubuntu10.04(2.6.32-24) has bugs about FIFREESE/FITHAW ioctl which will cause the failure of ioctl and may hang the system.
# >
# > As a result, the customer could ether updating linux kernel or using old vmware tools to avoid this issue.
# >
# > I update customer's VM kernel from 2.6.32-24 to 2.6.35-22 and the quiesce snapshot could success.
# > The ova is uploaded IBM_Test_with_new_kernel.ova. It includes 2 snapshot: one is using the customer's old kernel and the other is using a newer linux kernel.
# >
# >
# >
# >
# >
# >
#
# KB has been updated.
# Cause:
# The cause of this issue is a problem in the 2.6.32-24 kernel with the FIFREESE/FITHAW ioctl feature within the guest which is utilized to quiesce the Linux filesystem.
# Resolution:
# To resolve this issue, update the kernel of your linux guest virtual machine to 2.6.35-22 or higher.
#
# http://knova-prod-kcc-vip.vmware.com:8080/contactcenter/php/search.do?cmd=displayKC&docType=kc&externalId=2038606_draft&sliceId=2&docTypeID=DT_KB_1_1&dialogID=722538690&stateId=1%200%20722676477
# 20
# *****
# Would anyone have the Kernel bug no. for this issue?
# 21
# *****
# (In reply to comment #23)
# > The root cause is that:
# > The old vmware tools sent "ioctl(handle, SYNC_IOC_THAW)" to vmsync driver to do the quiesce snapshot, and the vmsync driver implement the process of SYNC_IOC_THAW ioctl.
# > Since Linux kernel 2.6.32, the kernel itself started to support FIFREESE/FITHAW ioctl, and no need to use our vmsync driver.
# > Unfortunately, the customer's ubuntu10.04(2.6.32-24) has bugs about FIFREESE/FITHAW ioctl which will cause the failure of ioctl and may hang the system.
# >
# > As a result, the customer could ether updating linux kernel or using old vmware tools to avoid this issue.
# >
# > I update customer's VM kernel from 2.6.32-24 to 2.6.35-22 and the quiesce snapshot could success.
# > The ova is uploaded IBM_Test_with_new_kernel.ova. It includes 2 snapshot: one is using the customer's old kernel and the other is using a newer linux kernel.
# >
# >
#
# Would it be possible for you to tell me where you sourced this information from as I have a customer (SR 13267518401) who wishes to query Redhat about this issue and as such would like a kerenl bug number?
# 22
# *****
# Hi Maurice,
#
# The conclusion is derived from my expermients, and I didn't find out that kernel bug number.
#
# Thanks.
# 23
# *****
# Fujitsu gave us a valuable  information.
#
# Redhat bug#768304 has a resolution for FIFREEZE hang issue which is addressed by RHEL 6.4.
#
# HTH.
# 24
# *****
# Thanks  Akira to offer this valuable information.
# Should we add that to KB(Update #34)?
# 25
# *****
# FYI, more info from Fujitsu: RHEL @ 5.4 kernel 2.6.18-164.el5 already implements the FIFREEZE and seems to work with 5.1 tools :
#
# ------------------------------------------
# RHEL 5.4?source
# ------------------------------------------
# include/linux/fs.h
#
#  234 #define FIFREEZE        _IOWR('X', 119, int)    /* Freeze */
#  235 #define FITHAW          _IOWR('X', 120, int)    /* Thaw */
#
#
# ======================================================================
# RHEL 5.3
# ======================================================================
# [root@localhost ~]# cat /etc/redhat-release
# Red Hat Enterprise Linux Server release 5.3 (Tikanga)
# [root@localhost ~]# uname -a
# >Linux localhost.localdomain 2.6.18-128.el5 #1 SMP Wed Dec 17 11:42:39 EST 2008 i686 i686 i386 GNU/Linux
# [root@localhost ~]# ps aux | grep toolsd
# root      2670  0.0  0.3  28968  3960 ?        S    15:08   0:00 /usr/sbin/vmtoolsd
# root      3875  0.0  0.0   4980   788 pts/1    S+   15:12   0:00 grep toolsd
#
# [root@localhost ~]# strace -p 2670 2>&1 | grep -Ei "ioctl|sync"
# ...
# ioctl(20, 0xc0045877, 0x19e204)         = -1 ENOTTY (Inappropriate ioctl for device)
# open("/proc/driver/vmware-sync", O_RDONLY|O_LARGEFILE) = 20
# ...
#
# ======================================================================
# RHEL 5.4
# ======================================================================
# Last login: Tue Apr 23 15:11:39 2013
# [root@localhost ~]# cat /etc/redhat-release
# Red Hat Enterprise Linux Server release 5.4 (Tikanga)
# [root@localhost ~]# uname -a
# >Linux localhost.localdomain 2.6.18-164.el5 #1 SMP Tue Aug 18 15:51:48 EDT 2009 x86_64 x86_64 x86_64 GNU/Linux
# [root@localhost ~]# ps aux | grep toolsd
# root      2507  0.0  0.4 138408  4312 ?        S    15:11   0:00 /usr/sbin/vmtoolsd
# root      3704  0.0  1.5 220708 15904 ?        Sl   15:11   0:00 /usr/lib/vmware-tools/sbin64/vmtoolsd -n vmusr
# root      3969  0.0  0.0  65388   820 pts/1    R+   15:20   0:00 grep toolsd
#
# [root@localhost ~]# strace -p 2507 2>&1 | grep -Ei "ioctl|sync"
# ...
# ioctl(20, 0xc0045877, 0)                = 0 *
# ioctl(21, 0xc0045877, 0)                = -1 EOPNOTSUPP (Operation not supported)
# ioctl(21, 0xc0045877, 0)                = -1 EOPNOTSUPP (Operation not supported)
# ioctl(21, 0xc0045877, 0)                = -1 EOPNOTSUPP (Operation not supported)
# ioctl(21, 0xc0045877, 0)                = 0 *
# ioctl(22, 0xc0045877, 0)                = -1 EOPNOTSUPP (Operation not supported)
# ioctl(22, 0xc0045877, 0)                = -1 EOPNOTSUPP (Operation not supported)
# ioctl(22, 0xc0045877, 0)                = -1 EOPNOTSUPP (Operation not supported)
# ioctl(20, 0xc0045878, 0x2b352e13abc0)   = 0
# ioctl(21, 0xc0045878, 0x2b352e13abc0)   = 0
# ...
# 26
# *****
# (In reply to comment #44)
# > Thanks  Akira to offer this valuable information.
# > Should we add that to KB(Update #34)?
# >
# >
#
# Sounds good to me.
# What changes need to be made to the article? Taking Akiras latest post into consideration.
# 27
# *****
# (In reply to comment #46)
# > (In reply to comment #44)
# >
# > Thanks  Akira to offer this valuable information.
# > Should we add that to KB(Update #34)?
# >
# >
# >
# >
# > Sounds good to me.
# > What changes need to be made to the article? Taking Akiras latest post into consideration.
# I think adding the redhat kernel bug number is more convictive to our customers.
# 28
# *****
# (In reply to comment #47)
# > (In reply to comment #46)
# >
# > (In reply to comment #44)
# >
# > Thanks  Akira to offer this valuable information.
# > Should we add that to KB(Update #34)?
# >
# >
# >
# >
# > Sounds good to me.
# > What changes need to be made to the article? Taking Akiras latest post into consideration.
# >
# > I think adding the redhat kernel bug number is more convictive to our customers.
# >
# >
#
# The article has been updated with the Redhat bug number as requested.
# http://knova-prod-kcc-vip.vmware.com:8080/contactcenter/php/search.do?cmd=displayKC&docType=kc&externalId=2038606_draft&sliceId=2&docTypeID=DT_KB_1_1&dialogID=810634936&stateId=1%200%20810788223
# 29
# *****
# It is root caused (Update #23), and a new KB is for it (Update #48).
# 30
# *****
# (In reply to comment #53)
# >
# 31
# *****
# Is there any chance to add this to the Release Notes?
#
# I had SR: 13319801605. where the customer asked specific to add this to the Release Notes.
#
# Thank you,
#
# Steffen
# 32
# *****
# (In reply to comment #55)
# > Is there any chance to add this to the Release Notes?
# > I had SR: 13319801605. where the customer asked specific to add this to the Release Notes.
# 33
# *****
# Question ... Do we know if this issue has been resolved with 5.1 U1 tools?   Is this affecting just process through Vsphere client or overall snapshot quiescing
# 34
# *****
# (In reply to comment #58)
# > Question ... Do we know if this issue has been resolved with 5.1 U1 tools?   Is this affecting just process through Vsphere client or overall snapshot quiescing
# >
# It's not accurate to say whether this issue is resolved in 51u1 tools or not, since the quiesce snapshot mechanisms are different.
# 1)esx50 tools should always use vmware vmsync driver to do the quiesce snapshot.
# 2)esx51 tools would firstly try Linux kernel fs freeze ioctl(latest kernel would support it, maybe > 2.6.29? I don't remember very clear). If that failed, then try vmware vmsync driver to do so(if CU selected the option of vmsync installation).
#
# This bug is due to Linux kernel fs freeze bug in certificate version.
#
# So 2 solutions are:
# 1) Using old version tools which would always us vmsync driver rather than kernel's freeze ioctl.
# 2) Changing to a newer Linux kernel whose freeze bug is already fixed.
#
# Thanks
# Tim
# 35
# *****
# (In reply to comment #59)
# > (In reply to comment #58)
# >
# > Question ... Do we know if this issue has been resolved with 5.1 U1 tools?   Is this affecting just process through Vsphere client or overall snapshot quiescing
# >
# >
# > It's not accurate to say whether this issue is resolved in 51u1 tools or not, since the quiesce snapshot mechanisms are different.
# > 1)esx50 tools should always use vmware vmsync driver to do the quiesce snapshot.
# > 2)esx51 tools would firstly try Linux kernel fs freeze ioctl(latest kernel would support it, maybe > 2.6.29? I don't remember very clear). If that failed, then try vmware vmsync driver to do so(if CU selected the option of vmsync installation).
# >
# > This bug is due to Linux kernel fs freeze bug in certificate version.
# >
# > So 2 solutions are:
# > 1) Using old version tools which would always us vmsync driver rather than kernel's freeze ioctl.
# > 2) Changing to a newer Linux kernel whose freeze bug is already fixed.
# >
# > Thanks
# > Tim
# >
# >
#
# Thanks Tim, totally understand and agree, but my customer is a cloud service provider, so having all their customers upgrade their kernel is a little more difficult than most.  Is there any way (even un-documented) to force the 5.1 tools to use vmsync driver first?  Also, is this a documented Linux bug that I can point them to?
# 36
# *****
# > Thanks Tim, totally understand and agree, but my customer is a cloud service provider, so having all their customers upgrade their kernel is a little more difficult than most.  Is there any way (even un-documented) to force the 5.1 tools to use vmsync driver first?
# Unfortunately, the program logic of 5.1 tools is constant, except changing to 5.0 tools.
# A workaround is:
# Add these lines to the tools.conf file(http://knova-prod-kcc-vip.vmware.com:8080/contactcenter/php/search.do?cmd=displayKC&docType=kc&externalId=2038606&sliceId=2&plainview=null&docTypeID=DT_KB_1_1&micrositeID=MS_Agent):
#
# [vmbackup]
# enableSyncDriver = false
#
# But that workaround would only do a sync operation before snapshot, and would not FREEZE fs and not block latter write IOs until the snapshot is done(through THAW IOCTL).
#
# >Also, is this a documented Linux bug that I can point them to?
# Red Hat has addressed this in bug 768304.
# 37
# *****
# (In reply to comment #62)
# > Thanks Tim, totally understand and agree, but my customer is a cloud service provider, so having all their customers upgrade their kernel is a little more difficult than most.  Is there any way (even un-documented) to force the 5.1 tools to use vmsync driver first?
# >
# > Unfortunately, the program logic of 5.1 tools is constant, except changing to 5.0 tools.
# > A workaround is:
# > Add these lines to the tools.conf file(http://knova-prod-kcc-vip.vmware.com:8080/contactcenter/php/search.do?cmd=displayKC&docType=kc&externalId=2038606&sliceId=2&plainview=null&docTypeID=DT_KB_1_1&micrositeID=MS_Agent):
# >
# > [vmbackup]
# > enableSyncDriver = false
# >
# > But that workaround would only do a sync operation before snapshot, and would not FREEZE fs and not block latter write IOs until the snapshot is done(through THAW IOCTL).
# >
# >
# > Also, is this a documented Linux bug that I can point them to?
# >
# > Red Hat has addressed this in bug 768304.
# >
# >
#
# Hi Le,
#
# I am requesting some clarification for my customer in SR 13369342109. Based on  Update #59, you mentioned 5.1 tools uses Guest Sync driver and if it fails, falls back to use vm sync. You also mentioned to use 5.0 tools as an option which defaults to vm sync which seems to contradict the work-around 'enableSyncDriver = false' for 5.1? Also I would like to know other than the sync providers used, are there any differences between the vm sync drivers in 5.0 and 5.1?
# 38
# *****
# (In reply to comment #73)
# > (In reply to comment #62)
# >
# > Thanks Tim, totally understand and agree, but my customer is a cloud service provider, so having all their customers upgrade their kernel is a little more difficult than most.  Is there any way (even un-documented) to force the 5.1 tools to use vmsync driver first?
# >
# > Unfortunately, the program logic of 5.1 tools is constant, except changing to 5.0 tools.
# > A workaround is:
# > Add these lines to the tools.conf file(http://knova-prod-kcc-vip.vmware.com:8080/contactcenter/php/search.do?cmd=displayKC&docType=kc&externalId=2038606&sliceId=2&plainview=null&docTypeID=DT_KB_1_1&micrositeID=MS_Agent):
# >
# > [vmbackup]
# > enableSyncDriver = false
# >
# > But that workaround would only do a sync operation before snapshot, and would not FREEZE fs and not block latter write IOs until the snapshot is done(through THAW IOCTL).
# >
# >
# > Also, is this a documented Linux bug that I can point them to?
# >
# > Red Hat has addressed this in bug 768304.
# >
# >
# >
# >
# > Hi Le,
# >
# > I am requesting some clarification for my customer in SR 13369342109. Based on  Update #59, you mentioned 5.1 tools uses Guest Sync driver and if it fails, falls back to use vm sync. You also mentioned to use 5.0 tools as an option which defaults to vm sync which seems to contradict the work-around 'enableSyncDriver = false' for 5.1?
#
# The work-around 'enableSyncDriver = false' for 5.1 would not guarantee the data consistency of quiesce snapshot.
# Because we found the some RHEL 2.6.18.xxx version had FREEZE/THAW IOCTL bug, the work-around to use 5.0 tools would force to use our vmsync driver of that kernel version which could bypass the RHEL kernel bug.
#
# > Also I would like to know other than the sync providers used, are there any differences between the vm sync drivers in 5.0 and 5.1?
# I don't see much large changes of vmsync drivers in 5.0 and 5.1 from codes aspect. While one thing need to know is that there would be no vmsync driver on ship for the linux kernel version > 2.6.30. So for that newer kernel, CU have to use the linux kernel's IOCTL mechnism.
#
# Thanks
# Tim
# 39
# *****
# (In reply to comment #76)
# > (In reply to comment #73)
# >
# > (In reply to comment #62)
# >
# > Thanks Tim, totally understand and agree, but my customer is a cloud service provider, so having all their customers upgrade their kernel is a little more difficult than most.  Is there any way (even un-documented) to force the 5.1 tools to use vmsync driver first?
# >
# > Unfortunately, the program logic of 5.1 tools is constant, except changing to 5.0 tools.
# > A workaround is:
# > Add these lines to the tools.conf file(http://knova-prod-kcc-vip.vmware.com:8080/contactcenter/php/search.do?cmd=displayKC&docType=kc&externalId=2038606&sliceId=2&plainview=null&docTypeID=DT_KB_1_1&micrositeID=MS_Agent):
# >
# > [vmbackup]
# > enableSyncDriver = false
# >
# > But that workaround would only do a sync operation before snapshot, and would not FREEZE fs and not block latter write IOs until the snapshot is done(through THAW IOCTL).
# >
# >
# > Also, is this a documented Linux bug that I can point them to?
# >
# > Red Hat has addressed this in bug 768304.
# >
# >
# >
# >
# > Hi Le,
# >
# > I am requesting some clarification for my customer in SR 13369342109. Based on  Update #59, you mentioned 5.1 tools uses Guest Sync driver and if it fails, falls back to use vm sync. You also mentioned to use 5.0 tools as an option which defaults to vm sync which seems to contradict the work-around 'enableSyncDriver = false' for 5.1?
# >
# >
# > The work-around 'enableSyncDriver = false' for 5.1 would not guarantee the data consistency of quiesce snapshot.
# > Because we found the some RHEL 2.6.18.xxx version had FREEZE/THAW IOCTL bug, the work-around to use 5.0 tools would force to use our vmsync driver of that kernel version which could bypass the RHEL kernel bug.
#
# Typo, not 2.6.18.xxx, should be 2.6.32.xxx.
#
# >
# >
# > Also I would like to know other than the sync providers used, are there any differences between the vm sync drivers in 5.0 and 5.1?
# >
# > I don't see much large changes of vmsync drivers in 5.0 and 5.1 from codes aspect. While one thing need to know is that there would be no vmsync driver on ship for the linux kernel version > 2.6.30. So for that newer kernel, CU have to use the linux kernel's IOCTL mechnism.
#
# Typo, not > 2.6.30, should be > 3.0. Sorry for that.
#
# >
# > Thanks
# > Tim
# >
# >

# %%
for line in df.loc[3]['thetext'].splitlines():
    print line,"***"

# print df.loc[3]['thetext']
# print rm_cite(df.loc[3]['thetext'])
print df.loc[0]['thetext']
# print tokenizestem_to_string(df.loc[0]['thetext'])
print preprocess_strict(df.loc[0]['thetext'], "string")
# Out:
# (In reply to comment #0) ***
# > Which VMs in questions have problems: .ova attached to the PR ***
# > Guest OS VMX File Path: .ova attached to the PR ***
#  ***
# What are the login credentials (root/???) for the attached .ova VM? ***
# SR ID: SR  12224870309
# Customer: IBM / GMT (+1 DST) / cool
# Product Version/Build Numbers: VMware Tools 9.0.0 build-782409
# Regressed from previous release?: NA
# Frequency: repruducible
# Time of Failure/Last Occurrence: NA
# Time Skew between various machines?: NA
# Recent Changes to the Environment? Upgrade to 5.1 GA
# Date Opened in Support: 2012-09-24
# Guest: Ubuntu 10.04 (2.6.32-24-generic #39-Ubuntu SMP)
# Server IP/Hostname: NA
# Problem description: Snapshot task for a Linux VM fails with
#
# "An error occurred while quiescing the virtual machine. See the virtual machine's event log for details."
#
# According to the customer, this only happens for 5.1, not for an 5.0 or 4.x Tools (which makes sense, because as far as I can see, the "new" freeze is only in the most recent Tools),
#
# Impact: IBM is concerned that their customers will have issues with their backup software, which by default sets the quiesce flag.
# Which VMs in questions have problems: .ova attached to the PR
# Guest OS VMX File Path: .ova attached to the PR
# Logs/files location: repro details below / .ova attached to the PR
#
# Installed Tools from the linux.iso and followed the default selections (e.g. no on vmsync)
#
# created /etc/vmware/tools.conf with:
#
# [logging]
# log = true
# vmsvc.level = debug
# vmsvc.handler = vmx
# vmbackup.level = debug
# vmbackup.handler = vmx
#
# customers VM: (2.6.32-24-generic #39-Ubuntu SMP) when a user is logged on (tty1)
#
# 2012-10-11T11:13:11.683Z| vcpu-0| I120: ToolsBackup: changing quiesce state: IDLE -> STARTED
# 2012-10-11T11:13:12.683Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupAsyncCallback
# 2012-10-11T11:13:12.683Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] VmBackupAsyncCallback: checking VmBackupOnFreeze
# 2012-10-11T11:13:12.683Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] Async request 'VmBackupOnFreeze' completed
# 2012-10-11T11:13:12.683Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupEnableSync
# 2012-10-11T11:13:12.684Z| vcpu-0| I120: Guest: [    info] [vmsvc:guestinfo] Poll loop disabled.
# 2012-10-11T11:13:12.684Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupSyncDriverStart
# 2012-10-11T11:13:12.684Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmsvc] SyncDriver: Freezing using Linux ioctls...
# 2012-10-11T11:13:30.356Z| vmx| I120: GuestRpcSendTimedOut: message to toolbox timed out.
#
#
# my VM: (2.6.32-21-generic #32-Ubuntu SMP) when a user is logged on (tty1)
#
# 2012-10-11T10:50:25.347Z| vcpu-0| I120: ToolsBackup: changing quiesce state: IDLE -> STARTED
# 2012-10-11T10:50:26.347Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupAsyncCallback
# 2012-10-11T10:50:26.347Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] VmBackupAsyncCallback: checking VmBackupOnFreeze
# 2012-10-11T10:50:26.347Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] Async request 'VmBackupOnFreeze' completed
# 2012-10-11T10:50:26.347Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupEnableSync
# 2012-10-11T10:50:26.347Z| vcpu-0| I120: Guest: [    info] [vmsvc:guestinfo] Poll loop disabled.
# 2012-10-11T10:50:26.347Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupSyncDriverStart
# 2012-10-11T10:50:26.348Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmsvc] SyncDriver: Freezing using Linux ioctls...
# 2012-10-11T10:50:26.381Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmsvc] SyncDriver: successfully froze '/'.
#
# Sometimes, the customers VM "hangs" after a failed snapshot, errors similar to this can be seen on another tty:
#
# INFO: task rsyslogd:692 blocked for more than 120 seconds.
# "echo 0 > /proc/sys/kernel/hung_task_timeout_secs" disables this message.
#
# INFO: task vmtoolsd:1078 blocked for more than 120 seconds.
# "echo 0 > /proc/sys/kernel/hung_task_timeout_secs" disables this message.
#
# INFO: task flush-8:0:1116 blocked for more than 120 seconds.
# "echo 0 > /proc/sys/kernel/hung_task_timeout_secs" disables this message.
#
#
#
# https://opengrok.eng.vmware.com/source/xref/vsphere5x.perforce.1666/bora-vmsoft/lib/syncDriver/syncDriverLinux.c#95
#
# /*
#  *******************************************************************************
#  * LinuxDriver_Freeze --                                                  */ /**
#  *
#  * Tries to freeze the filesystems using the Linux kernel's FIFREEZE ioctl.
#  *
#  * If the first attempt at using the ioctl fails, assume that it doesn't exist
#  * and return SD_UNAVAILABLE, so that other means of freezing are tried.
#  *
#  * @param[in]  paths    Paths to freeze (colon-separated).
#  * @param[out] handle   Handle to use for thawing.
#  *
#  * @return A SyncDriverErr.
#  *
#  *******************************************************************************
#  */
#
# SyncDriverErr
# LinuxDriver_Freeze(const char *paths,
#                    SyncDriverHandle *handle)
# {
#    char *path;
#    int fd;
#    size_t count = 0;
#    unsigned int index = 0;
#    Bool first = TRUE;
#    DynBuf fds;
#    LinuxDriver *sync = NULL;
#    SyncDriverErr err = SD_SUCCESS;
#
#    DynBuf_Init(&fds);
#
#    Debug(LGPFX "Freezing using Linux ioctls...\n");
#
#    sync = calloc(1, sizeof *sync);
#    if (sync == NULL) {
#       return SD_ERROR;
#    }
#
#    sync->driver.thaw = LinuxFiThaw;
#    sync->driver.close = LinuxFiClose;
#
#
# Here an excerpt from my setup with samples_on:
#
# 2012-10-11T12:16:43.607Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupStart
# 2012-10-11T12:16:43.607Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] Using quiesceApps = 1, quiesceFS = 1, allowHWProvider = 1,execScripts = 1, scriptArg = , timeout = 0
# 2012-10-11T12:16:43.607Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] Quiescing volumes: (null)
# 2012-10-11T12:16:43.607Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackup_SendEvent
# 2012-10-11T12:16:43.608Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupStartScripts
# 2012-10-11T12:16:43.608Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] Trying to run scripts from /etc/vmware-tools/backupScripts.d
# 2012-10-11T12:16:43.608Z| vcpu-0| I120: ToolsBackup: changing quiesce state: IDLE -> STARTED
# 2012-10-11T12:16:44.270Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:44.359Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmtoolsd] Setting option 'broadcastIP' to '1'.
# 2012-10-11T12:16:44.497Z| vcpu-0| I120: HBACommon: First write on scsi0:0.fileName='/vmfs/volumes/50754a72-c3572cc0-2f5e-002522e84d6a/UbuntuQuiescedSnapshotErrorCustomerVM-12224870309/UbuntuQuiescedSnapshotErrorCustomerVM-12224870309.vmdk'
# 2012-10-11T12:16:44.497Z| vcpu-0| I120: DDB: "longContentID" = "44e94886a09462321d590fdb367ce74e" (was "74b6dd73b99ed05d2138b442b84cc479")
# 2012-10-11T12:16:44.532Z| vcpu-0| I120: DISKLIB-CHAIN : DiskChainUpdateContentID: old=0xb84cc479, new=0x367ce74e (44e94886a09462321d590fdb367ce74e)
# 2012-10-11T12:16:44.607Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupAsyncCallback
# 2012-10-11T12:16:44.607Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] VmBackupAsyncCallback: checking VmBackupOnFreeze
# 2012-10-11T12:16:44.607Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] Async request 'VmBackupOnFreeze' completed
# 2012-10-11T12:16:44.608Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupEnableSync
# 2012-10-11T12:16:44.608Z| vcpu-0| I120: Guest: [    info] [vmsvc:guestinfo] Poll loop disabled.
# 2012-10-11T12:16:44.608Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmbackup] *** VmBackupSyncDriverStart
# 2012-10-11T12:16:44.608Z| vcpu-0| I120: Guest: [   debug] [vmsvc:vmsvc] SyncDriver: Freezing using Linux ioctls...
# 2012-10-11T12:16:45.283Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:46.299Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:47.315Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:48.331Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:49.351Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:49.791Z| vmx| I120: GuestRpcSendTimedOut: message to toolbox timed out.
# 2012-10-11T12:16:50.369Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:51.387Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:52.405Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:53.423Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:54.441Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:55.459Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:56.473Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:57.493Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:58.511Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:16:59.525Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:17:00.543Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:17:01.559Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:17:02.579Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:17:03.595Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:17:04.611Z| vcpu-0| I120: VMSAMPLE: cs=0x60, rip=0xc012988a
# 2012-10-11T12:17:04.793Z| vmx| I120: GuestRpcSendTimedOut: message to toolbox timed out.
# 2012-10-11T12:17:04.793Z| vmx| I120: GuestRpc: app toolbox's second ping timeout; assuming app is down
# 2012-10-11T12:17:04.793Z| vmx| I120: ToolsBackup: changing quiesce state: STARTED -> DONE
# 2012-10-11T12:17:04.793Z| vmx| I120: SnapshotVMXTakeSnapshotComplete: done with snapshot 'sdfdaf': 0
# 2012-10-11T12:17:04.793Z| vmx| I120: SnapshotVMXTakeSnapshotComplete: Snapshot 0 failed: Failed to quiesce the virtual machine (40).
#
#
# vmware-5.log and vmss file (suspended the VM after the snapshot failed) are attached as well, just in case.
#
# UbuntuQuiescedSnapshotErrorCustomerVM-12224870309-de861639.vmss.gz - md5sum 23ffd0d31c310b08cbbbfd31125a0720
#
#
# Steps to reproduce / what led to this:
# ======================================
# Issue Reproducible? Y - with the customers VM
# GSS Repro Attempt Status: Y, could not reproduce on Ubuntu 12.04 / 10.04, although with a slightly different version (2.6.32-21-generic #32-Ubuntu SMP)
#
# Find details for my whitebox below:
#
# vCenter: 10.26.165.145
# User: administrator
# Password: VMware123
#
# The VMs display name is: UbuntuQuiescedSnapshotErrorCustomerVM-12224870309
# It can be reached via SSH on: 10.26.165.227
# User: root
# Password: quiesce
#
# Note that sometimes taking quiesced snapshots just works, in that case just reboot the VM and log on to a tty, it seems that it fails more often when a user is logged on (over the MKS). It might have been coincidences though.
#
# Troubleshooting done or workarounds applied:
# ============================================
# BY TS: tried to reproduce the issue, couldn't without the customers VM though
# BY Customer:  only workaround is to not select quiece when snapshotting
# Research conducted: found no matching PRs
# Customer Expectations/Next Steps: fix if VMware issue (the customer is aware that this might be a Linux kernel bug), explanation if there is a way to ignore the quiesce from the VMs point of view / not use the new freeze feature
# sr id sr custom ibm gmt dst cool product version build number vmware tool build regress previous releas na frequenc repruduc time failur last occurr na time skew various machin na recent chang environ upgrad ga date open support guest ubuntu generic ubuntu smp server ip hostnam na problem descript snapshot task linux vm fail error occur quiesc virtual machin see virtual machin event log detail accord custom happen x tool make sens far see new freez recent tool impact ibm concern custom issu backup softwar default set quiesc flag vms question problem ova attach pr guest os vmx file path ova attach pr log file locat repro detail ova attach pr instal tool linux iso follow default select e g vmsync creat etc vmware tool conf log log true vmsvc level debug vmsvc handler vmx vmbackup level debug vmbackup handler vmx custom vm generic ubuntu smp user log tti z vcpu toolsbackup chang quiesc state idl start z vcpu guest debug vmsvc vmbackup vmbackupasynccallback z vcpu guest debug vmsvc vmbackup vmbackupasynccallback check vmbackuponfreez z vcpu guest debug vmsvc vmbackup async request vmbackuponfreez complet z vcpu guest debug vmsvc vmbackup vmbackupenablesync z vcpu guest info vmsvc guestinfo poll loop disabl z vcpu guest debug vmsvc vmbackup vmbackupsyncdriverstart z vcpu guest debug vmsvc vmsvc syncdriv freez use linux ioctl z vmx guestrpcsendtimedout messag toolbox time vm generic ubuntu smp user log tti z vcpu toolsbackup chang quiesc state idl start z vcpu guest debug vmsvc vmbackup vmbackupasynccallback z vcpu guest debug vmsvc vmbackup vmbackupasynccallback check vmbackuponfreez z vcpu guest debug vmsvc vmbackup async request vmbackuponfreez complet z vcpu guest debug vmsvc vmbackup vmbackupenablesync z vcpu guest info vmsvc guestinfo poll loop disabl z vcpu guest debug vmsvc vmbackup vmbackupsyncdriverstart z vcpu guest debug vmsvc vmsvc syncdriv freez use linux ioctl z vcpu guest debug vmsvc vmsvc syncdriv success froze sometim custom vm hang fail snapshot error similar seen anoth tti info task rsyslogd block second echo proc sys kernel hung task timeout sec disabl messag info task vmtoolsd block second echo proc sys kernel hung task timeout sec disabl messag info task flush block second echo proc sys kernel hung task timeout sec disabl messag linuxdriv freez tri freez filesystem use linux kernel fifreez ioctl first attempt use ioctl fail assum doesn exist return sd unavail mean freez tri param path path freez colon separ param handl handl use thaw return syncdrivererr syncdrivererr linuxdriv freez const char path syncdriverhandl handl char path int fd size count unsign int index bool first true dynbuf fds linuxdriv sync null syncdrivererr err sd success dynbuf init fds debug lgpfx freez use linux ioctl n sync calloc sizeof sync sync null return sd error sync driver thaw linuxfithaw sync driver close linuxficlos excerpt setup sampl z vcpu guest debug vmsvc vmbackup vmbackupstart z vcpu guest debug vmsvc vmbackup use quiesceapp quiescef allowhwprovid execscript scriptarg timeout z vcpu guest debug vmsvc vmbackup quiesc volum null z vcpu guest debug vmsvc vmbackup vmbackup sendev z vcpu guest debug vmsvc vmbackup vmbackupstartscript z vcpu guest debug vmsvc vmbackup tri run script etc vmware tool backupscript d z vcpu toolsbackup chang quiesc state idl start z vcpu vmsampl cs x rip xc z vcpu guest debug vmsvc vmtoolsd set option broadcastip z vcpu hbacommon first write scsi filenam vmfs volum c cc f e e d ubuntuquiescedsnapshoterrorcustomervm ubuntuquiescedsnapshoterrorcustomervm vmdk z vcpu ddb longcontentid e d fdb ce e b dd b ed d b b cc z vcpu disklib chain diskchainupdatecontentid old xb cc new x ce e e d fdb ce e z vcpu guest debug vmsvc vmbackup vmbackupasynccallback z vcpu guest debug vmsvc vmbackup vmbackupasynccallback check vmbackuponfreez z vcpu guest debug vmsvc vmbackup async request vmbackuponfreez complet z vcpu guest debug vmsvc vmbackup vmbackupenablesync z vcpu guest info vmsvc guestinfo poll loop disabl z v ...

# %%
def preprocess_mild( raw_description):
    # Function to convert a raw bug description to a list of words or a cleared string, it's "mild" in the sense that it removes words that don't contain letters
    # Remove markers
    # text = BeautifulSoup(raw_description).get_text() 
    
    # Remove cites
    description = rm_cite(raw_description)
    print description
    
    # Remove urls
    text = re.sub("((mailto\:|(news|(ht|f)tp(s?))\://){1}\S+)", " ", description)
    text = re.sub("[^\x00-\x7f]", " ", text)
    
    # Convert to lower case, tokenize
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    filtered_tokens = []
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    
    # Remove stop words
    stopwords = set(nltk.corpus.stopwords.words('english'))
    meaningful_tokens = [token for token in filtered_tokens if not token in stopwords]
    print " ".join(meaningful_tokens)
    
    # Stemming
    snowball = SnowballStemmer("english")
    stems = [snowball.stem(t) for t in meaningful_tokens]
    print " ".join(stems)

# %%
conn_data = MySQLdb.connect(host='10.117.8.41', port=3306, user='root', passwd='vmware', db='bugdata')
cur_data =conn_data.cursor()

sql_ld = '''SELECT thetext
FROM longdescs
WHERE bug_id = 794510'''
cur_data.execute(sql_ld)
text = cur_data.fetchall()
for item in text:
    print '''"*****"'''
    print item[0]
    preprocess_mild(item[0])
# Out:
# "*****"
# ESX Information:
# ----------------
# Type : Thin
# Build : ESX 5.0U1 536624
# Test Machine : cpdbj-252.eng.vmware.com(10.117.9.133)
# Login Credentials : root/ca$h...
# Guest VM: windows8-64
# Client OS: windowsxp sp2 32bit
#
#
# Test case details:
# ----
# 1. Create windows8 Virtual machine and install windows8 developer preview build.
#    xHCI USB controller is added by default.
# 2. Install VMware tools.
# 3. Connected USB3.0 devices to client OS.
#    The devices are Kinston DT ultimate USB3.0 flash driver and buslink USB3.0 hard driver.
#    Both devices works well for read/write sanity test on physical machine.
# 4. Client connect the USB3.0 devices to the guest.
#    ==> failed
#        And the devices also get disconnected from the client OS.
#
# Expected result: USB3 devices should be OK to add to the VM.
# Actual result: USB3 devices cannot be connected to VM.
#
# Captured Logs and their location:
# ---
# Will put usbarb log and vi-client log from client OS to the ftp-access.
# ESX Information:
# ----------------
# Type : Thin
# Build : ESX 5.0U1 536624
# Test Machine : cpdbj-252.eng.vmware.com(10.117.9.133)
# Login Credentials : root/ca$h...
# Guest VM: windows8-64
# Client OS: windowsxp sp2 32bit
#
#
# Test case details:
# ----
# 1. Create windows8 Virtual machine and install windows8 developer preview build.
#    xHCI USB controller is added by default.
# 2. Install VMware tools.
# 3. Connected USB3.0 devices to client OS.
#    The devices are Kinston DT ultimate USB3.0 flash driver and buslink USB3.0 hard driver.
#    Both devices works well for read/write sanity test on physical machine.
# 4. Client connect the USB3.0 devices to the guest.
#    ==> failed
#        And the devices also get disconnected from the client OS.
#
# Expected result: USB3 devices should be OK to add to the VM.
# Actual result: USB3 devices cannot be connected to VM.
#
# Captured Logs and their location:
# ---
# Will put usbarb log and vi-client log from client OS to the ftp-access.
# ESX Information Type Thin Build ESX 5.0U1 Test Machine cpdbj-252.eng.vmware.com Login Credentials root/ca h Guest VM windows8-64 Client OS windowsxp sp2 32bit Test case details Create windows8 Virtual machine install windows8 developer preview build xHCI USB controller added default Install VMware tools Connected USB3.0 devices client OS The devices Kinston DT ultimate USB3.0 flash driver buslink USB3.0 hard driver Both devices works well read/write sanity test physical machine Client connect USB3.0 devices guest failed And devices also get disconnected client OS Expected result USB3 devices OK add VM Actual result USB3 devices connected VM Captured Logs location Will put usbarb log vi-client log client OS ftp-access
# esx inform type thin build esx 5.0u1 test machin cpdbj-252.eng.vmware.com login credenti root/ca h guest vm windows8-64 client os windowsxp sp2 32bit test case detail creat windows8 virtual machin instal windows8 develop preview build xhci usb control ad default instal vmware tool connect usb3.0 devic client os the devic kinston dt ultim usb3.0 flash driver buslink usb3.0 hard driver both devic work well read/writ saniti test physic machin client connect usb3.0 devic guest fail and devic also get disconnect client os expect result usb3 devic ok add vm actual result usb3 devic connect vm captur log locat will put usbarb log vi-client log client os ftp-access
# "*****"
# vi-client.log says connection failed for timeout.
#
# [viclient:SoapTran:M: 6] 2011-12-06 17:41:34.932  Invoke 96 Finish QueryConfigOption on EnvironmentBrowser:14-envmgr [10.117.9.133] - Serial:0.033, Server:000.106
# [        :QuickInf:M: 6] 2011-12-06 17:41:38.244  CDM----ConnRequest.Enqueue, vm: 14, key: path:1/9/1 version:2, requestType: Connect, VMRC state: VMRC_CS_CONNECTED
# [        :QuickInf:M: 6] 2011-12-06 17:41:38.244  CDM----ConnRequest.Dequeue, vm: 14, key: path:1/9/1 version:2, requestType: Connect, requests left: 0, VMRC state: VMRC_CS_CONNECTED
# [        :QuickInf:M: 6] 2011-12-06 17:41:38.244  CDM--ConnectDevice key: path:1/9/1 version:2, currentVm: 14, VMRC state: VMRC_CS_CONNECTED
# [        :QuickInf:M: 6] 2011-12-06 17:41:38.260  CDM--ConnectDevice returned: True, VMRC state: VMRC_CS_CONNECTED
# [        :PerfInfo:P: 9] 2011-12-06 17:42:27.072  [Hndl:GDI=302][Hndl:User=262][Hndl:Kernel=847][Mem:WS=131821568 (125.71 MB)][Mem:VirtualUsed=423550976 (403.93 MB)][Mem:PrivateUsed=116789248 (111.38 MB)][Mem:NETUsed=25957144 (24.75 MB)][Mem:PF=116789248 (111.38 MB)][Mem:PagedUsed=575460 (561.97 KB)][Mem:NonPagedUsed=36224 (35.38 KB)][CPU:Threads=25][CPU:Total=00:00:11.2656250][CPU:User=00:00:09.6875000][CPU:Kernel=00:00:01.5781250]
# [viclient:SoapTran:W:17] 2011-12-06 17:42:28.150  Invoke 25 Finish WaitForUpdates on PropertyCollector:session[52bf57da-dfbd-7cc9-5cd9-aa05346b01c4]527ca80b-5589-8089-28c1-c9b33885af1e [10.117.9.133] - Serial:0.000, Server:900.004
# Suppressed: VirtualInfrastructure.Soap.MethodInvocationSoapImpl: The request failed because the remote server '10.117.9.133' took too long to respond. (The command has timed out as the remote server is taking too long to respond.)
# [viclient:Error   :W:17] 2011-12-06 17:42:28.150  ConnectionError occurred while executing WFU
# VirtualInfrastructure.Exceptions.RequestTimedOut: The request failed because the remote server '10.117.9.133' took too long to respond. (The command has timed out as the remote server is taking too long to respond.)
#
#
#
# vmware-usbarb-system.log says the devices is occupied by some other.
# --------
# 2011-12-06T17:29:14.093+08:00| vthread-5| W110: USBArb: Connecting device 0x900000009511652 to client 5452
# 2011-12-06T17:31:28.404+08:00| vthread-5| W110: USBArb: Connect failed: The semaphore timeout period has expired (121)
# 2011-12-06T17:31:28.404+08:00| vthread-5| W110: USBArb: Failed to connect device:900000009511652 to '10.117.9.133:/vmfs/volumes/4a8a2dd1-12723378-0ac0-001f29c47ae0/windows8-64/windows8-64.vmx', status:4
# 2011-12-06T17:31:28.404+08:00| vthread-5| W110: USBArb: Client 5452 trying to close id 900000009511652 it doesn't own.
# 2011-12-06T17:41:24.650+08:00| vthread-5| W110: UsbgWinGetHubPortProperty: CM_Get_DevNode_Registry_PropertyW returned 25 getting property E
# 2011-12-06T17:41:38.853+08:00| vthread-5| W110: USBArb: Connecting device 0x900000109511652 to client 5452
# 2011-12-06T17:43:14.806+08:00| vthread-5| W110: UsbgWinGetHubPortProperty: CM_Get_DevNode_Registry_PropertyW returned 25 getting property E
# 2011-12-06T17:43:52.884+08:00| vthread-5| W110: USBArb: Connect failed: The semaphore timeout period has expired (121)
# 2011-12-06T17:43:52.884+08:00| vthread-5| W110: USBArb: Failed to connect device:900000109511652 to '10.117.9.133:/vmfs/volumes/4a8a2dd1-12723378-0ac0-001f29c47ae0/windows8-64/windows8-64.vmx', status:4
# 2011-12-06T17:43:52.884+08:00| vthread-5| W110: USBArb: Client 5452 trying to close id 900000109511652 it doesn't own.
# 2011-12-06T17:51:36.553+08:00| vthread-5| W110: USBArb: Connecting device 0x90000000caf5000 to client 5452
# 2011-12-06T17:51:38.881+08:00| vthread-6| W110: USBGW: Descriptor request failed: The requested resource is in use (170)
# 2011-12-06T17:51:38.881+08:00| vthread-5| W110: UsbgWinGetHubPortProperty: CM_Get_DevNode_Registry_PropertyW returned 25 getting property E
# 2011-12-06T17:53:52.802+08:00| vthread-5| W110: USBArb: Connect failed: The semaphore timeout period has expired (121)
# 2011-12-06T17:53:52.802+08:00| vthread-5| W110: USBArb: Failed to connect device:90000000caf5000 to '10.117.9.133:/vmfs/volumes/4a8a2dd1-12723378-0ac0-001f29c47ae0/windows8-64/windows8-64.vmx', status:4
# 2011-12-06T17:53:52.802+08:00| vthread-5| W110: USBArb: Client 5452 trying to close id 90000000caf5000 it doesn't own.
# vi-client.log says connection failed for timeout.
#
# [viclient:SoapTran:M: 6] 2011-12-06 17:41:34.932  Invoke 96 Finish QueryConfigOption on EnvironmentBrowser:14-envmgr [10.117.9.133] - Serial:0.033, Server:000.106
# [        :QuickInf:M: 6] 2011-12-06 17:41:38.244  CDM----ConnRequest.Enqueue, vm: 14, key: path:1/9/1 version:2, requestType: Connect, VMRC state: VMRC_CS_CONNECTED
# [        :QuickInf:M: 6] 2011-12-06 17:41:38.244  CDM----ConnRequest.Dequeue, vm: 14, key: path:1/9/1 version:2, requestType: Connect, requests left: 0, VMRC state: VMRC_CS_CONNECTED
# [        :QuickInf:M: 6] 2011-12-06 17:41:38.244  CDM--ConnectDevice key: path:1/9/1 version:2, currentVm: 14, VMRC state: VMRC_CS_CONNECTED
# [        :QuickInf:M: 6] 2011-12-06 17:41:38.260  CDM--ConnectDevice returned: True, VMRC state: VMRC_CS_CONNECTED
# [        :PerfInfo:P: 9] 2011-12-06 17:42:27.072  [Hndl:GDI=302][Hndl:User=262][Hndl:Kernel=847][Mem:WS=131821568 (125.71 MB)][Mem:VirtualUsed=423550976 (403.93 MB)][Mem:PrivateUsed=116789248 (111.38 MB)][Mem:NETUsed=25957144 (24.75 MB)][Mem:PF=116789248 (111.38 MB)][Mem:PagedUsed=575460 (561.97 KB)][Mem:NonPagedUsed=36224 (35.38 KB)][CPU:Threads=25][CPU:Total=00:00:11.2656250][CPU:User=00:00:09.6875000][CPU:Kernel=00:00:01.5781250]
# [viclient:SoapTran:W:17] 2011-12-06 17:42:28.150  Invoke 25 Finish WaitForUpdates on PropertyCollector:session[52bf57da-dfbd-7cc9-5cd9-aa05346b01c4]527ca80b-5589-8089-28c1-c9b33885af1e [10.117.9.133] - Serial:0.000, Server:900.004
# Suppressed: VirtualInfrastructure.Soap.MethodInvocationSoapImpl: The request failed because the remote server '10.117.9.133' took too long to respond. (The command has timed out as the remote server is taking too long to respond.)
# [viclient:Error   :W:17] 2011-12-06 17:42:28.150  ConnectionError occurred while executing WFU
# VirtualInfrastructure.Exceptions.RequestTimedOut: The request failed because the remote server '10.117.9.133' took too long to respond. (The command has timed out as the remote server is taking too long to respond.)
#
#
#
# vmware-usbarb-system.log says the devices is occupied by some other.
# --------
# 2011-12-06T17:29:14.093+08:00| vthread-5| W110: USBArb: Connecting device 0x900000009511652 to client 5452
# 2011-12-06T17:31:28.404+08:00| vthread-5| W110: USBArb: Connect failed: The semaphore timeout period has expired (121)
# 2011-12-06T17:31:28.404+08:00| vthread-5| W110: USBArb: Failed to connect device:900000009511652 to '10.117.9.133:/vmfs/volumes/4a8a2dd1-12723378-0ac0-001f29c47ae0/windows8-64/windows8-64.vmx', status:4
# 2011-12-06T17:31:28.404+08:00| vthread-5| W110: USBArb: Client 5452 trying to close id 900000009511652 it doesn't own.
# 2011-12-06T17:41:24.650+08:00| vthread-5| W110: UsbgWinGetHubPortProperty: CM_Get_DevNode_Registry_PropertyW returned 25 getting property E
# 2011-12-06T17:41:38.853+08:00| vthread-5| W110: USBArb: Connecting device 0x900000109511652 to client 5452
# 2011-12-06T17:43:14.806+08:00| vthread-5| W110: UsbgWinGetHubPortProperty: CM_Get_DevNode_Registry_PropertyW returned 25 getting property E
# 2011-12-06T17:43:52.884+08:00| vthread-5| W110: USBArb: Connect failed: The semaphore timeout period has expired (121)
# 2011-12-06T17:43:52.884+08:00| vthread-5| W110: USBArb: Failed to connect device:900000109511652 to '10.117.9.133:/vmfs/volumes/4a8a2dd1-12723378-0ac0-001f29c47ae0/windows8-64/windows8-64.vmx', status:4
# 2011-12-06T17:43:52.884+08:00| vthread-5| W110: USBArb: Client 5452 trying to close id 900000109511652 it doesn't own.
# 2011-12-06T17:51:36.553+08:00| vthread-5| W110: USBArb: Connecting device 0x90000000caf5000 to client 5452
# 2011-12-06T17:51:38.881+08:00| vthread-6| W110: USBGW: Descriptor request failed: The requested resource is in use (170)
# 2011-12-06T17:51:38.881+08:00| vthread-5| W110: UsbgWinGetHubPortProperty: CM_Get_DevNode_Registry_PropertyW returned 25 getting property E
# 2011-12-06T17:53:52.802+08:00| vthread-5| W110: USBArb: Connect failed: The semaphore timeout period has expired (121)
# 2011-12-06T17:53:52.802+08:00| vthread-5| W110: USBArb: Failed to connect device:90000000caf5000 to '10.117.9.133:/vmfs/volumes/4a8a2dd1-12723378-0ac0-001f29c47ae0/windows8-64/windows8-64.vmx', status:4
# 2011-12-06T17:53:52.802+08:00| vthread-5| W110: USBArb: Client 5452 trying to close id 90000000caf5000 it doesn't own.
# vi-client.log says connection failed timeout viclient SoapTran M Invoke Finish QueryConfigOption EnvironmentBrowser:14-envmgr Serial:0.033 Server:000.106 QuickInf M CDM ConnRequest.Enqueue vm key path:1/9/1 version:2 requestType Connect VMRC state VMRC_CS_CONNECTED QuickInf M CDM ConnRequest.Dequeue vm key path:1/9/1 version:2 requestType Connect requests left VMRC state VMRC_CS_CONNECTED QuickInf M CDM ConnectDevice key path:1/9/1 version:2 currentVm VMRC state VMRC_CS_CONNECTED QuickInf M CDM ConnectDevice returned True VMRC state VMRC_CS_CONNECTED PerfInfo P Hndl GDI=302 Hndl User=262 Hndl Kernel=847 Mem WS=131821568 MB Mem VirtualUsed=423550976 MB Mem PrivateUsed=116789248 MB Mem NETUsed=25957144 MB Mem PF=116789248 MB Mem PagedUsed=575460 KB Mem NonPagedUsed=36224 KB CPU Threads=25 CPU Total=00:00:11.2656250 CPU User=00:00:09.6875000 CPU Kernel=00:00:01.5781250 viclient SoapTran W:17 Invoke Finish WaitForUpdates PropertyCollector session 52bf57da-dfbd-7cc9-5cd9-aa05346b01c4 527ca80b-5589-8089-28c1-c9b33885af1e Serial:0.000 Server:900.004 Suppressed VirtualInfrastructure.Soap.MethodInvocationSoapImpl The request failed remote server took long respond The command timed remote server taking long respond viclient Error W:17 ConnectionError occurred executing WFU VirtualInfrastructure.Exceptions.RequestTimedOut The request failed remote server took long respond The command timed remote server taking long respond vmware-usbarb-system.log says devices occupied 2011-12-06T17:29:14.093+08:00| vthread-5| W110 USBArb Connecting device 0x900000009511652 client 2011-12-06T17:31:28.404+08:00| vthread-5| W110 USBArb Connect failed The semaphore timeout period expired 2011-12-06T17:31:28.404+08:00| vthread-5| W110 USBArb Failed connect device:900000009511652 /vmfs/volumes/4a8a2dd1-12723378-0ac0-001f29c47ae0/windows8-64/windows8-64.vmx status:4 2011-12-06T17:31:28.404+08:00| vthread-5| W110 USBArb Client trying close id n't 2011-12-06T17:41:24.650+08:00| vthread-5| W110 UsbgWinGetHubPortProperty CM_Get_DevNode_Registry_PropertyW returned getting property E 2011-12-06T17:41:38.853+08:00| vthread-5| W110 USBArb Connecting device 0x900000109511652 client 2011-12-06T17:43:14.806+08:00| vthread-5| W110 UsbgWinGetHubPortProperty CM_Get_DevNode_Registry_PropertyW returned getting property E 2011-12-06T17:43:52.884+08:00| vthread-5| W110 USBArb Connect failed The semaphore timeout period expired 2011-12-06T17:43:52.884+08:00| vthread-5| W110 USBArb Failed connect device:900000109511652 /vmfs/volumes/4a8a2dd1-12723378-0ac0-001f29c47ae0/windows8-64/windows8-64.vmx status:4 2011-12-06T17:43:52.884+08:00| vthread-5| W110 USBArb Client trying close id n't 2011-12-06T17:51:36.553+08:00| vthread-5| W110 USBArb Connecting device 0x90000000caf5000 client 2011-12-06T17:51:38.881+08:00| vthread-6| W110 USBGW Descriptor request failed The requested resource use 2011-12-06T17:51:38.881+08:00| vthread-5| W110 UsbgWinGetHubPortProperty CM_Get_DevNode_Registry_PropertyW returned getting property E 2011-12-06T17:53:52.802+08:00| vthread-5| W110 USBArb Connect failed The semaphore timeout period expired 2011-12-06T17:53:52.802+08:00| vthread-5| W110 USBArb Failed connect device:90000000caf5000 /vmfs/volumes/4a8a2dd1-12723378-0ac0-001f29c47ae0/windows8-64/windows8-64.vmx status:4 2011-12-06T17:53:52.802+08:00| vthread-5| W110 USBArb Client trying close id 90000000caf5000 n't
# vi-client.log say connect fail timeout viclient soaptran m invok finish queryconfigopt environmentbrowser:14-envmgr serial:0.033 server:000.106 quickinf m cdm connrequest.enqueu vm key path:1/9/1 version:2 requesttyp connect vmrc state vmrc_cs_connect quickinf m cdm connrequest.dequeu vm key path:1/9/1 version:2 requesttyp connect request left vmrc state vmrc_cs_connect quickinf m cdm connectdevic key path:1/9/1 version:2 currentvm vmrc state vmrc_cs_connect quickinf m cdm connectdevic return true vmrc state vmrc_cs_connect perfinfo p hndl gdi=302 hndl user=262 hndl kernel=847 mem ws=131821568 mb mem virtualused=423550976 mb mem privateused=116789248 mb mem netused=25957144 mb mem pf=116789248 mb mem pagedused=575460 kb mem nonpagedused=36224 kb cpu threads=25 cpu total=00:00:11.2656250 cpu user=00:00:09.6875000 cpu kernel=00:00:01.5781250 viclient soaptran w:17 invok finish waitforupd propertycollector session 52bf57da-dfbd-7cc9-5cd9-aa05346b01c4 527ca80b-5589-8089-28c1-c9b33885af1 serial:0.000 server:900.004 suppress virtualinfrastructure.soap.methodinvocationsoapimpl the request fail remot server took long respond the command time remot server take long respond viclient error w:17 connectionerror occur execut wfu virtualinfrastructure.exceptions.requesttimedout the request fail remot server took long respond the command time remot server take long respond vmware-usbarb-system.log say devic occupi 2011-12-06t17:29:14.093+08:00| vthread-5| w110 usbarb connect devic 0x900000009511652 client 2011-12-06t17:31:28.404+08:00| vthread-5| w110 usbarb connect fail the semaphor timeout period expir 2011-12-06t17:31:28.404+08:00| vthread-5| w110 usbarb fail connect device:900000009511652 /vmfs/volumes/4a8a2dd1-12723378-0ac0-001f29c47ae0/windows8-64/windows8-64.vmx status:4 2011-12-06t17:31:28.404+08:00| vthread-5| w110 usbarb client tri close id n't 2011-12-06t17:41:24.650+08:00| vthread-5| w110 usbgwingethubportproperti cm_get_devnode_registry_propertyw return get properti e 2011-12-06t17:41:38.853+08:00| vthread-5| w110 usbarb connect devic 0x900000109511652 client 2011-12-06t17:43:14.806+08:00| vthread-5| w110 usbgwingethubportproperti cm_get_devnode_registry_propertyw return get properti e 2011-12-06t17:43:52.884+08:00| vthread-5| w110 usbarb connect fail the semaphor timeout period expir 2011-12-06t17:43:52.884+08:00| vthread-5| w110 usbarb fail connect device:900000109511652 /vmfs/volumes/4a8a2dd1-12723378-0ac0-001f29c47ae0/windows8-64/windows8-64.vmx status:4 2011-12-06t17:43:52.884+08:00| vthread-5| w110 usbarb client tri close id n't 2011-12-06t17:51:36.553+08:00| vthread-5| w110 usbarb connect devic 0x90000000caf5000 client 2011-12-06t17:51:38.881+08:00| vthread-6| w110 usbgw descriptor request fail the request resourc use 2011-12-06t17:51:38.881+08:00| vthread-5| w110 usbgwingethubportproperti cm_get_devnode_registry_propertyw return get properti e 2011-12-06t17:53:52.802+08:00| vthread-5| w110 usbarb connect fail the semaphor timeout period expir 2011-12-06t17:53:52.802+08:00| vthread-5| w110 usbarb fail connect device:90000000caf5000 /vmfs/volumes/4a8a2dd1-12723378-0ac0-001f29c47ae0/windows8-64/windows8-64.vmx status:4 2011-12-06t17:53:52.802+08:00| vthread-5| w110 usbarb client tri close id 90000000caf5000 n't
# "*****"
# Nothing special from vmkernel.log vmware.log or host usb.log.
# Any more information you need, please let me know.
#
# kevin
# Nothing special from vmkernel.log vmware.log or host usb.log.
# Any more information you need, please let me know.
#
# kevin
# Nothing special vmkernel.log vmware.log host usb.log Any information need please let know kevin
# noth special vmkernel.log vmware.log host usb.log ani inform need pleas let know kevin
# "*****"
# 2011-12-05T16:48:32.578+08:00| vthread-5| W110: USBArb: Failed to connect device:900000009511652 to '10.117.9.133:/vmfs/volumes/4a8a2dd1-12723378-0ac0-001f29c47ae0/windows8-64/windows8-64.vmx', status:4
#
# It looks like hcmon is having trouble claiming the device for some reason. I think the next steps are the following:
# 1) Verify that this reproduces on vsphere5x.
# 2) Use the new hcmon debugging capabilities in vsphere5x to figure out what went wrong (we have kernel driver logging that we can use on that branch).
#
# Also a few other things:
# 1) Please include the vmware.log files when filing bugs.
# 2) Please include the client vmrc log as well.
#
# What type of controller was the USB 3.0 device connected to on the client machine? XHCI? If so what drivers were you running on the client machine? NEC? What version?
# 2011-12-05T16:48:32.578+08:00| vthread-5| W110: USBArb: Failed to connect device:900000009511652 to '10.117.9.133:/vmfs/volumes/4a8a2dd1-12723378-0ac0-001f29c47ae0/windows8-64/windows8-64.vmx', status:4
#
# It looks like hcmon is having trouble claiming the device for some reason. I think the next steps are the following:
# 1) Verify that this reproduces on vsphere5x.
# 2) Use the new hcmon debugging capabilities in vsphere5x to figure out what went wrong (we have kernel driver logging that we can use on that branch).
#
# Also a few other things:
# 1) Please include the vmware.log files when filing bugs.
# 2) Please include the client vmrc log as well.
#
# What type of controller was the USB 3.0 device connected to on the client machine? XHCI? If so what drivers were you running on the client machine? NEC? What version?
# 2011-12-05T16:48:32.578+08:00| vthread-5| W110 USBArb Failed connect device:900000009511652 /vmfs/volumes/4a8a2dd1-12723378-0ac0-001f29c47ae0/windows8-64/windows8-64.vmx status:4 It looks like hcmon trouble claiming device reason I think next steps following Verify reproduces vsphere5x Use new hcmon debugging capabilities vsphere5x figure went wrong kernel driver logging use branch Also things Please include vmware.log files filing bugs Please include client vmrc log well What type controller USB device connected client machine XHCI If drivers running client machine NEC What version
# 2011-12-05t16:48:32.578+08:00| vthread-5| w110 usbarb fail connect device:900000009511652 /vmfs/volumes/4a8a2dd1-12723378-0ac0-001f29c47ae0/windows8-64/windows8-64.vmx status:4 it look like hcmon troubl claim devic reason i think next step follow verifi reproduc vsphere5x use new hcmon debug capabl vsphere5x figur went wrong kernel driver log use branch also thing pleas includ vmware.log file file bug pleas includ client vmrc log well what type control usb devic connect client machin xhci if driver run client machin nec what version
# "*****"
# win8 GOS support in 50u1 is PMT 4822
# win8 GOS support in 50u1 is PMT 4822
# win8 GOS support 50u1 PMT
# win8 gos support 50u1 pmt
# "*****"
# (In reply to comment #3)
# > Also a few other things:
# > 1) Please include the vmware.log files when filing bugs.
# > 2) Please include the client vmrc log as well.
#
# Thanks Aaron for figuring out.
# I have attached vmware.log and vmrc logs as well to ftp-access. Please check them out.
# ESX is using UTC time zone, while client is in GMT+8 (9 hours ahead of the host).
#
#
# >
# > What type of controller was the USB 3.0 device connected to on the client machine? XHCI? If so what drivers were you running on the client machine? NEC? What version?
# >
#
# Yes ,it's xHCI. Only one xHCI controller exists on the VM.
# The client OS driver is NEC USB3.0 controller version 1.0.19.0.
# See attached image for driver information.
#
# Thanks Aaron for figuring out.
# I have attached vmware.log and vmrc logs as well to ftp-access. Please check them out.
# ESX is using UTC time zone, while client is in GMT+8 (9 hours ahead of the host).
#
#
# >
# > What type of controller was the USB 3.0 device connected to on the client machine? XHCI? If so what drivers were you running on the client machine? NEC? What version?
# >
#
# Yes ,it's xHCI. Only one xHCI controller exists on the VM.
# The client OS driver is NEC USB3.0 controller version 1.0.19.0.
# See attached image for driver information.
# Thanks Aaron figuring I attached vmware.log vmrc logs well ftp-access Please check ESX using UTC time zone client GMT+8 hours ahead host What type controller USB device connected client machine XHCI If drivers running client machine NEC What version Yes 's xHCI Only one xHCI controller exists VM The client OS driver NEC USB3.0 controller version See attached image driver information
# thank aaron figur i attach vmware.log vmrc log well ftp-access pleas check esx use utc time zone client gmt+8 hour ahead host what type control usb devic connect client machin xhci if driver run client machin nec what version yes 's xhci onli one xhci control exist vm the client os driver nec usb3.0 control version see attach imag driver inform
# "*****"
# from vmrc log,
#
#
# 2011-12-06T17:51:24.022+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDevices: dispGetPhysicalClientDevices - type 4.
# 2011-12-06T17:51:24.022+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDevices: Devices type mask - 4.
# 2011-12-06T17:51:24.022+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDevices (0x0008): { "path:1/3/2 version:2", "path:1/9/0 version:2", }
# 2011-12-06T17:51:24.022+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDevices: Enumerated 2 devices.
# 2011-12-06T17:51:24.022+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/3/2 version:2".
# 2011-12-06T17:51:24.022+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/3/2 version:2".
# 2011-12-06T17:51:24.022+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDeviceDetails: { key: "path:1/3/2 version:2", type: USB, state: "disconnected", name: "SanDisk U3 Cruzer Micro", path: "1/3/2", usbID: 125916166, usbFamilies: 0x00000400, "not sharable", usbSpeeds: 0x00000004 }
# 2011-12-06T17:51:24.022+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device details found.
# 2011-12-06T17:51:24.022+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/9/0 version:2".
# 2011-12-06T17:51:24.022+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/9/0 version:2".
# 2011-12-06T17:51:24.022+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDeviceDetails: { key: "path:1/9/0 version:2", type: USB, state: "disconnected", name: "Buslink Removable Disk", path: "1/9/0", usbID: 212815872, usbFamilies: 0x00000400, "not sharable", usbSpeeds: 0x00000008 }
# 2011-12-06T17:51:24.022+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device details found.
# 2011-12-06T17:51:34.397+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDevices: dispGetPhysicalClientDevices - type 4.
# 2011-12-06T17:51:34.397+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDevices: Devices type mask - 4.
# 2011-12-06T17:51:34.397+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDevices (0x0008): { "path:1/3/2 version:2", "path:1/9/0 version:2", }
# 2011-12-06T17:51:34.397+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDevices: Enumerated 2 devices.
# 2011-12-06T17:51:34.412+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/3/2 version:2".
# 2011-12-06T17:51:34.412+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/3/2 version:2".
# 2011-12-06T17:51:34.412+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDeviceDetails: { key: "path:1/3/2 version:2", type: USB, state: "disconnected", name: "SanDisk U3 Cruzer Micro", path: "1/3/2", usbID: 125916166, usbFamilies: 0x00000400, "not sharable", usbSpeeds: 0x00000004 }
# 2011-12-06T17:51:34.412+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device details found.
# 2011-12-06T17:51:34.412+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/9/0 version:2".
# 2011-12-06T17:51:34.412+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/9/0 version:2".
# 2011-12-06T17:51:34.412+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDeviceDetails: { key: "path:1/9/0 version:2", type: USB, state: "disconnected", name: "Buslink Removable Disk", path: "1/9/0", usbID: 212815872, usbFamilies: 0x00000400, "not sharable", usbSpeeds: 0x00000008 }
# 2011-12-06T17:51:34.412+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device details found.
# 2011-12-06T17:51:35.928+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/9/0 version:2".
# 2011-12-06T17:51:35.928+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/9/0 version:2".
# 2011-12-06T17:51:35.928+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDeviceDetails: { key: "path:1/9/0 version:2", type: USB, state: "disconnected", name: "Buslink Removable Disk", path: "1/9/0", usbID: 212815872, usbFamilies: 0x00000400, "not sharable", usbSpeeds: 0x00000008 }
# 2011-12-06T17:51:35.928+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device details found.
# 2011-12-06T17:51:35.943+08:00| device_vmrc| cui::vmrc::DeviceCnx::Connect: Connect device "path:1/9/0 version:2" on VM "14"
# 2011-12-06T17:51:35.943+08:00| device_vmrc| cui::VMTicketingVIM::AcquireTicket
# 2011-12-06T17:51:35.943+08:00| device_vmrc| cui::VMTicketingVIM::AcquireTicket - AUTO_QUEUING - can acquire ticket now, acquiring
# 2011-12-06T17:51:35.943+08:00| device_vmrc| cui::VMTicketingVIM::DoAcquireTicket
# 2011-12-06T17:51:35.943+08:00| device_vmrc| cui::VMTicketingVIM::DoAcquireTicket - issuing ticket acquisition request
# 2011-12-06T17:51:36.053+08:00| device_vmrc| cui::VMTicketingVIM::OnAcquiredTicket
# 2011-12-06T17:51:36.053+08:00| device_vmrc| REM-USB: Opening device 0x90000000caf5000
# 2011-12-06T17:51:36.553+08:00| device_vmrc| REMDEV:RemoteDeviceConnected USB reconnecting:0
# 2011-12-06T17:51:36.553+08:00| device_vmrc| REM-USB: Connecting device 0x90000000caf5000
# 2011-12-06T17:51:36.553+08:00| device_vmrc| USBGW: Write arbitrator op:8 len:8
# 2011-12-06T17:51:36.553+08:00| device_vmrc| USB Hint: A USB device is about to be unplugged from the host and connected to this virtual machine. It will first be stopped to enable safe removal. With some devices, the host may display the message "The device can now safely be removed."
# 2011-12-06T17:51:36.553+08:00| device_vmrc|
# 2011-12-06T17:51:36.553+08:00| device_vmrc| USBGW: Write arbitrator op:6 len:99
# 2011-12-06T17:51:42.146+08:00| device_vmrc| USBGW: Write arbitrator op:8 len:8
# 2011-12-06T17:51:42.146+08:00| device_vmrc| USBGW: Write arbitrator op:8 len:8
# 2011-12-06T17:51:42.146+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices: USB devices changed
# 2011-12-06T17:52:15.396+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDevices: dispGetPhysicalClientDevices - type 4.
# 2011-12-06T17:52:15.396+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDevices: Devices type mask - 4.
# 2011-12-06T17:52:15.396+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDevices (0x0008): { "path:1/3/2 version:2", "path:1/9/0 version:2", }
# 2011-12-06T17:52:15.396+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDevices: Enumerated 2 devices.
# 2011-12-06T17:52:15.396+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/3/2 version:2".
# 2011-12-06T17:52:15.396+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/3/2 version:2".
# 2011-12-06T17:52:15.396+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDeviceDetails: { key: "path:1/3/2 version:2", type: USB, state: "disconnected", name: "SanDisk U3 Cruzer Micro", path: "1/3/2", usbID: 125916166, usbFamilies: 0x00000400, "not sharable", usbSpeeds: 0x00000004 }
# 2011-12-06T17:52:15.396+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device details found.
# 2011-12-06T17:52:15.396+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/9/0 version:2".
# 2011-12-06T17:52:15.396+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/9/0 version:2".
# 2011-12-06T17:52:15.396+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDeviceDetails: { key: "path:1/9/0 version:2", type: USB, state: "connected", name: "Buslink Removable Disk", path: "1/9/0", usbID: 212815872, usbFamilies: 0x00000400, "not sharable", usbSpeeds: 0x00000008 }
# 2011-12-06T17:52:15.396+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device details found.
# 2011-12-06T17:53:01.177+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDevices: dispGetPhysicalClientDevices - type 4.
# 2011-12-06T17:53:01.177+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDevices: Devices type mask - 4.
# 2011-12-06T17:53:01.177+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDevices (0x0008): { "path:1/3/2 version:2", "path:1/9/0 version:2", }
# 2011-12-06T17:53:01.177+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDevices: Enumerated 2 devices.
# 2011-12-06T17:53:01.177+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/3/2 version:2".
# 2011-12-06T17:53:01.177+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/3/2 version:2".
# 2011-12-06T17:53:01.177+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDeviceDetails: { key: "path:1/3/2 version:2", type: USB, state: "disconnected", name: "SanDisk U3 Cruzer Micro", path: "1/3/2", usbID: 125916166, usbFamilies: 0x00000400, "not sharable", usbSpeeds: 0x00000004 }
# 2011-12-06T17:53:01.177+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device details found.
# 2011-12-06T17:53:01.177+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/9/0 version:2".
# 2011-12-06T17:53:01.177+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/9/0 version:2".
# 2011-12-06T17:53:01.177+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDeviceDetails: { key: "path:1/9/0 version:2", type: USB, state: "connected", name: "Buslink Removable Disk", path: "1/9/0", usbID: 212815872, usbFamilies: 0x00000400, "not sharable", usbSpeeds: 0x00000008 }
# 2011-12-06T17:53:01.177+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device details found.
# 2011-12-06T17:53:35.536+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDevices: dispGetPhysicalClientDevices - type 4.
# 2011-12-06T17:53:35.536+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDevices: Devices type mask - 4.
# 2011-12-06T17:53:35.536+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDevices (0x0008): { "path:1/3/2 version:2", "path:1/9/0 version:2", }
# 2011-12-06T17:53:35.536+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDevices: Enumerated 2 devices.
# 2011-12-06T17:53:35.536+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/3/2 version:2".
# 2011-12-06T17:53:35.536+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/3/2 version:2".
# 2011-12-06T17:53:35.536+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDeviceDetails: { key: "path:1/3/2 version:2", type: USB, state: "disconnected", name: "SanDisk U3 Cruzer Micro", path: "1/3/2", usbID: 125916166, usbFamilies: 0x00000400, "not sharable", usbSpeeds: 0x00000004 }
# 2011-12-06T17:53:35.536+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device details found.
# 2011-12-06T17:53:35.536+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/9/0 version:2".
# 2011-12-06T17:53:35.536+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/9/0 version:2".
# 2011-12-06T17:53:35.536+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDeviceDetails: { key: "path:1/9/0 version:2", type: USB, state: "connected", name: "Buslink Removable Disk", path: "1/9/0", usbID: 212815872, usbFamilies: 0x00000400, "not sharable", usbSpeeds: 0x00000008 }
# 2011-12-06T17:53:35.536+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device details found.
# 2011-12-06T17:53:52.802+08:00| device_vmrc| USBGA: Failed to connect device 90000000caf5000, error (4)
# 2011-12-06T17:53:52.802+08:00| device_vmrc| USB Message: The connection for the USB device "Buslink Removable Disk" was unsuccessful. Driver error.
# 2011-12-06T17:53:52.802+08:00| device_vmrc|
# 2011-12-06T17:53:52.802+08:00| device_vmrc| REM-USB: Doing an immediate disconnect of device 0x90000000caf5000
# 2011-12-06T17:53:52.802+08:00| device_vmrc| REM-USB: Disconnecting device 0x90000000caf5000
# 2011-12-06T17:53:52.802+08:00| device_vmrc| USBGW: Disconnecting device: 3E3B0AC id: 90000000caf5000
# 2011-12-06T17:53:52.802+08:00| device_vmrc| USBGW: Write arbitrator op:7 len:8
# 2011-12-06T17:53:52.802+08:00| device_vmrc| cui::vmrc::DeviceCnx::OnConnectAborted: Connect cancelled for device "path:1/9/0 version:2" on VM "14"
# 2011-12-06T17:53:52.802+08:00| device_vmrc| cui::vmrc::DeviceCnxMgr::EmitDeviceStateSignal: "disconnected" signal (requested) for device "path:1/9/0 version:2" on VM "14"
# 2011-12-06T17:53:52.802+08:00| device_vmrc| cui::vmrc::MessageMgr: "The device "Buslink Removable Disk" disconnected: the client requested disconnection."
# 2011-12-06T17:53:52.802+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/9/0 version:2".
# 2011-12-06T17:53:52.802+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/9/0 version:2".
# 2011-12-06T17:53:52.802+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDeviceDetails: { key: "path:1/9/0 version:2", type: USB, state: "connected", name: "Buslink Removable Disk", path: "1/9/0", usbID: 212815872, usbFamilies: 0x00000400, "not sharable", usbSpeeds: 0x00000008 }
# 2011-12-06T17:53:52.802+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device details found.
# 2011-12-06T17:53:53.864+08:00| device_vmrc| USBGW: Write arbitrator op:8 len:8
# 2011-12-06T17:53:53.864+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices: USB devices changed
# from vmrc log,
#
#
# 2011-12-06T17:51:24.022+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDevices: dispGetPhysicalClientDevices - type 4.
# 2011-12-06T17:51:24.022+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDevices: Devices type mask - 4.
# 2011-12-06T17:51:24.022+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDevices (0x0008): { "path:1/3/2 version:2", "path:1/9/0 version:2", }
# 2011-12-06T17:51:24.022+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDevices: Enumerated 2 devices.
# 2011-12-06T17:51:24.022+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/3/2 version:2".
# 2011-12-06T17:51:24.022+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/3/2 version:2".
# 2011-12-06T17:51:24.022+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDeviceDetails: { key: "path:1/3/2 version:2", type: USB, state: "disconnected", name: "SanDisk U3 Cruzer Micro", path: "1/3/2", usbID: 125916166, usbFamilies: 0x00000400, "not sharable", usbSpeeds: 0x00000004 }
# 2011-12-06T17:51:24.022+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device details found.
# 2011-12-06T17:51:24.022+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/9/0 version:2".
# 2011-12-06T17:51:24.022+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/9/0 version:2".
# 2011-12-06T17:51:24.022+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDeviceDetails: { key: "path:1/9/0 version:2", type: USB, state: "disconnected", name: "Buslink Removable Disk", path: "1/9/0", usbID: 212815872, usbFamilies: 0x00000400, "not sharable", usbSpeeds: 0x00000008 }
# 2011-12-06T17:51:24.022+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device details found.
# 2011-12-06T17:51:34.397+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDevices: dispGetPhysicalClientDevices - type 4.
# 2011-12-06T17:51:34.397+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDevices: Devices type mask - 4.
# 2011-12-06T17:51:34.397+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDevices (0x0008): { "path:1/3/2 version:2", "path:1/9/0 version:2", }
# 2011-12-06T17:51:34.397+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDevices: Enumerated 2 devices.
# 2011-12-06T17:51:34.412+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/3/2 version:2".
# 2011-12-06T17:51:34.412+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/3/2 version:2".
# 2011-12-06T17:51:34.412+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDeviceDetails: { key: "path:1/3/2 version:2", type: USB, state: "disconnected", name: "SanDisk U3 Cruzer Micro", path: "1/3/2", usbID: 125916166, usbFamilies: 0x00000400, "not sharable", usbSpeeds: 0x00000004 }
# 2011-12-06T17:51:34.412+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device details found.
# 2011-12-06T17:51:34.412+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/9/0 version:2".
# 2011-12-06T17:51:34.412+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/9/0 version:2".
# 2011-12-06T17:51:34.412+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDeviceDetails: { key: "path:1/9/0 version:2", type: USB, state: "disconnected", name: "Buslink Removable Disk", path: "1/9/0", usbID: 212815872, usbFamilies: 0x00000400, "not sharable", usbSpeeds: 0x00000008 }
# 2011-12-06T17:51:34.412+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device details found.
# 2011-12-06T17:51:35.928+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/9/0 version:2".
# 2011-12-06T17:51:35.928+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/9/0 version:2".
# 2011-12-06T17:51:35.928+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDeviceDetails: { key: "path:1/9/0 version:2", type: USB, state: "disconnected", name: "Buslink Removable Disk", path: "1/9/0", usbID: 212815872, usbFamilies: 0x00000400, "not sharable", usbSpeeds: 0x00000008 }
# 2011-12-06T17:51:35.928+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device details found.
# 2011-12-06T17:51:35.943+08:00| device_vmrc| cui::vmrc::DeviceCnx::Connect: Connect device "path:1/9/0 version:2" on VM "14"
# 2011-12-06T17:51:35.943+08:00| device_vmrc| cui::VMTicketingVIM::AcquireTicket
# 2011-12-06T17:51:35.943+08:00| device_vmrc| cui::VMTicketingVIM::AcquireTicket - AUTO_QUEUING - can acquire ticket now, acquiring
# 2011-12-06T17:51:35.943+08:00| device_vmrc| cui::VMTicketingVIM::DoAcquireTicket
# 2011-12-06T17:51:35.943+08:00| device_vmrc| cui::VMTicketingVIM::DoAcquireTicket - issuing ticket acquisition request
# 2011-12-06T17:51:36.053+08:00| device_vmrc| cui::VMTicketingVIM::OnAcquiredTicket
# 2011-12-06T17:51:36.053+08:00| device_vmrc| REM-USB: Opening device 0x90000000caf5000
# 2011-12-06T17:51:36.553+08:00| device_vmrc| REMDEV:RemoteDeviceConnected USB reconnecting:0
# 2011-12-06T17:51:36.553+08:00| device_vmrc| REM-USB: Connecting device 0x90000000caf5000
# 2011-12-06T17:51:36.553+08:00| device_vmrc| USBGW: Write arbitrator op:8 len:8
# 2011-12-06T17:51:36.553+08:00| device_vmrc| USB Hint: A USB device is about to be unplugged from the host and connected to this virtual machine. It will first be stopped to enable safe removal. With some devices, the host may display the message "The device can now safely be removed."
# 2011-12-06T17:51:36.553+08:00| device_vmrc|
# 2011-12-06T17:51:36.553+08:00| device_vmrc| USBGW: Write arbitrator op:6 len:99
# 2011-12-06T17:51:42.146+08:00| device_vmrc| USBGW: Write arbitrator op:8 len:8
# 2011-12-06T17:51:42.146+08:00| device_vmrc| USBGW: Write arbitrator op:8 len:8
# 2011-12-06T17:51:42.146+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices: USB devices changed
# 2011-12-06T17:52:15.396+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDevices: dispGetPhysicalClientDevices - type 4.
# 2011-12-06T17:52:15.396+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDevices: Devices type mask - 4.
# 2011-12-06T17:52:15.396+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDevices (0x0008): { "path:1/3/2 version:2", "path:1/9/0 version:2", }
# 2011-12-06T17:52:15.396+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDevices: Enumerated 2 devices.
# 2011-12-06T17:52:15.396+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/3/2 version:2".
# 2011-12-06T17:52:15.396+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/3/2 version:2".
# 2011-12-06T17:52:15.396+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDeviceDetails: { key: "path:1/3/2 version:2", type: USB, state: "disconnected", name: "SanDisk U3 Cruzer Micro", path: "1/3/2", usbID: 125916166, usbFamilies: 0x00000400, "not sharable", usbSpeeds: 0x00000004 }
# 2011-12-06T17:52:15.396+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device details found.
# 2011-12-06T17:52:15.396+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/9/0 version:2".
# 2011-12-06T17:52:15.396+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/9/0 version:2".
# 2011-12-06T17:52:15.396+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDeviceDetails: { key: "path:1/9/0 version:2", type: USB, state: "connected", name: "Buslink Removable Disk", path: "1/9/0", usbID: 212815872, usbFamilies: 0x00000400, "not sharable", usbSpeeds: 0x00000008 }
# 2011-12-06T17:52:15.396+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device details found.
# 2011-12-06T17:53:01.177+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDevices: dispGetPhysicalClientDevices - type 4.
# 2011-12-06T17:53:01.177+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDevices: Devices type mask - 4.
# 2011-12-06T17:53:01.177+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDevices (0x0008): { "path:1/3/2 version:2", "path:1/9/0 version:2", }
# 2011-12-06T17:53:01.177+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDevices: Enumerated 2 devices.
# 2011-12-06T17:53:01.177+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/3/2 version:2".
# 2011-12-06T17:53:01.177+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/3/2 version:2".
# 2011-12-06T17:53:01.177+08:00| device_vmrc| cui::vmrc::PhysicalClientDevices::GetDeviceDetails: { key: "path:1/3/2 version:2", type: USB, state: "disconnected", name: "SanDisk U3 Cruzer Micro", path: "1/3/2", usbID: 125916166, usbFamilies: 0x00000400, "not sharable", usbSpeeds: 0x00000004 }
# 2011-12-06T17:53:01.177+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device details found.
# 2011-12-06T17:53:01.177+08:00| device_vmrc| vmClientCore::VMControlDisp::GetPhysicalClientDeviceDetails: dispGetPhysicalClientDeviceDetails - device "path:1/9/0 version:2".
# 2011-12-06T17:53:01.177+08:00| device_vmrc| vmClientCore::VMControl::GetPhysicalClientDeviceDetails: Device "path:1/9/0 version:2".
# ...
#
# Thanks
# Kevin
# Hello Dyno I tried scenario latest vpx build unfortunately issue still exist Invalid Configuration Descriptor Both winXP win7 client covered Here build I using VPX build cs vmrc build cs usbarb build cs The steps upgrade VI client VMware-ciclient.exe upgrade VI client VMRC well For usbarb upgrade I copy files folder C \Program Files\Common Files\VMware\USB\ Please let know need information Thanks Kevin
# hello dyno i tri scenario latest vpx build unfortun issu still exist invalid configur descriptor both winxp win7 client cover here build i use vpx build cs vmrc build cs usbarb build cs the step upgrad vi client vmware-ciclient.ex upgrad vi client vmrc well for usbarb upgrad i copi file folder c \program files\common files\vmware\usb\ pleas let know need inform thank kevin
# "*****"
# Jack, I am reopening the PR based on comment#73.
#
# Dev team, can you please take a look ASAP as we are in GA phase of MNU2.
# Jack, I am reopening the PR based on comment#73.
#
# Dev team, can you please take a look ASAP as we are in GA phase of MNU2.
# Jack I reopening PR based comment Dev team please take look ASAP GA phase MNU2
# jack i reopen pr base comment dev team pleas take look asap ga phase mnu2
# "*****"
# Dyno, can you please follow-up? Thanks.
# Dyno, can you please follow-up? Thanks.
# Dyno please follow-up Thanks
# dyno pleas follow-up thank
# "*****"
# part of the fix is in hcmon. you need also replace %WINDIR%\system32\drivers\hcmon.sys
#
# ------------%<----------------
# net stop VMUsbArbService
# net stop hcmon
#
# rem replace %BINDIR% with your build
# copy %BINDIR%\hcmon.sys %WINDIR%\system32\drivers\
#
# net start hcmon
# net start VMUsbArbService
# ------------%<----------------
#
# but i really prefer you clean you env (uninstall any usbarb/vmrc compoments) then do the test.
# and the fix targets Windows XP.
# part of the fix is in hcmon. you need also replace %WINDIR%\system32\drivers\hcmon.sys
#
# ------------%<----------------
# net stop VMUsbArbService
# net stop hcmon
#
# rem replace %BINDIR% with your build
# copy %BINDIR%\hcmon.sys %WINDIR%\system32\drivers\
#
# net start hcmon
# net start VMUsbArbService
# ------------%<----------------
#
# but i really prefer you clean you env (uninstall any usbarb/vmrc compoments) then do the test.
# and the fix targets Windows XP.
# part fix hcmon need also replace WINDIR \system32\drivers\hcmon.sys net stop VMUsbArbService net stop hcmon rem replace BINDIR build copy BINDIR \hcmon.sys WINDIR \system32\drivers\ net start hcmon net start VMUsbArbService really prefer clean env uninstall usbarb/vmrc compoments test fix targets Windows XP
# part fix hcmon need also replac windir \system32\drivers\hcmon.si net stop vmusbarbservic net stop hcmon rem replac bindir build copi bindir \hcmon.si windir \system32\drivers\ net start hcmon net start vmusbarbservic realli prefer clean env uninstal usbarb/vmrc compoment test fix target window xp
# "*****"
# "Invalid Configuration Descriptor" is normal for this bug, check the review
# https://reviewboard.eng.vmware.com/r/335291/
#
# the fix is to address the "failed to client connect" problem.
#
# and quote Aaron's comment.
# """
# I believe what is happening is the client (windows xp) 3rd party driver is modifying the config descriptor before we can get it and windows xp doesn't like the modification. If so this is a known issue that isn't easy to fix (the missing superspeed companion endpoint descriptors have to be recreated).
# """
#
# Aaron,
#   is it still the situation or the above known issue get fixed?
# rgds,
# Dyno
# "Invalid Configuration Descriptor" is normal for this bug, check the review
# https://reviewboard.eng.vmware.com/r/335291/
#
# the fix is to address the "failed to client connect" problem.
#
# and quote Aaron's comment.
# """
# I believe what is happening is the client (windows xp) 3rd party driver is modifying the config descriptor before we can get it and windows xp doesn't like the modification. If so this is a known issue that isn't easy to fix (the missing superspeed companion endpoint descriptors have to be recreated).
# """
#
# Aaron,
#   is it still the situation or the above known issue get fixed?
# rgds,
# Dyno
# Invalid Configuration Descriptor normal bug check review fix address failed client connect problem quote Aaron 's comment. I believe happening client windows xp 3rd party driver modifying config descriptor get windows xp n't like modification If known issue n't easy fix missing superspeed companion endpoint descriptors recreated Aaron still situation known issue get fixed rgds Dyno
# invalid configur descriptor normal bug check review fix address fail client connect problem quot aaron 's comment. i believ happen client window xp 3rd parti driver modifi config descriptor get window xp n't like modif if known issu n't easi fix miss superspe companion endpoint descriptor recreat aaron still situat known issu get fix rgds dyno
# "*****"
# Added Prasadv(VCQE) in cc.
# Added Prasadv(VCQE) in cc.
# Added Prasadv VCQE cc
# ad prasadv vcqe cc
# "*****"
# Thanks Dyno for clarification.
#
# Here are my observations.
# 1. connect usb2.0 device to VM through xHCI controller
#    ==> OK
# 2. connect one single usb3.0 device to VM through xHCI controller
#    ==> connection is established, but cannot be recognized by windows8 VM
#        From device manager, "Invalid Configuration Descriptor" is reported.
#        This is expected behavior.
# 3. connect multiple usb3.0 devices to VM through xHCI controller (here is two. Voyager GT 3.0 or Kingston DT ultimate)
#    ==> connections are set, and both cannot be recognized by the VM.
#        the first one is reported as "Invalid Configuration Descriptor" and the second "Port Reset Failed"
#        This is not the exception.
#
# The builds I am using,
# ESX is latest recommended MNu2 GA1 build (873266).
#
# Client is winXP SP3 32bit.
# vpx(including vmrc& usbarb) has been upgraded to latest version.
#   VPX build, 866967 cs#1980676
#   vmrc build, 853999 cs#1967386
#   usbarb build, 854000 cs#1967381
# Thanks Dyno for clarification.
#
# Here are my observations.
# 1. connect usb2.0 device to VM through xHCI controller
#    ==> OK
# 2. connect one single usb3.0 device to VM through xHCI controller
#    ==> connection is established, but cannot be recognized by windows8 VM
#        From device manager, "Invalid Configuration Descriptor" is reported.
#        This is expected behavior.
# 3. connect multiple usb3.0 devices to VM through xHCI controller (here is two. Voyager GT 3.0 or Kingston DT ultimate)
#    ==> connections are set, and both cannot be recognized by the VM.
#        the first one is reported as "Invalid Configuration Descriptor" and the second "Port Reset Failed"
#        This is not the exception.
#
# The builds I am using,
# ESX is latest recommended MNu2 GA1 build (873266).
#
# Client is winXP SP3 32bit.
# vpx(including vmrc& usbarb) has been upgraded to latest version.
#   VPX build, 866967 cs#1980676
#   vmrc build, 853999 cs#1967386
#   usbarb build, 854000 cs#1967381
# Thanks Dyno clarification Here observations connect usb2.0 device VM xHCI controller OK connect one single usb3.0 device VM xHCI controller connection established recognized windows8 VM From device manager Invalid Configuration Descriptor reported This expected behavior connect multiple usb3.0 devices VM xHCI controller two Voyager GT Kingston DT ultimate connections set recognized VM first one reported Invalid Configuration Descriptor second Port Reset Failed This exception The builds I using ESX latest recommended MNu2 GA1 build Client winXP SP3 32bit vpx including vmrc usbarb upgraded latest version VPX build cs vmrc build cs usbarb build cs
# thank dyno clarif here observ connect usb2.0 devic vm xhci control ok connect one singl usb3.0 devic vm xhci control connect establish recogn windows8 vm from devic manag invalid configur descriptor report this expect behavior connect multipl usb3.0 devic vm xhci control two voyag gt kingston dt ultim connect set recogn vm first one report invalid configur descriptor second port reset fail this except the build i use esx latest recommend mnu2 ga1 build client winxp sp3 32bit vpx includ vmrc usbarb upgrad latest version vpx build cs vmrc build cs usbarb build cs
# "*****"
# Based on Update #77  do we need to update this in release notes.
# Based on Update #77  do we need to update this in release notes.
# Based Update need update release notes
# base updat need updat releas note
# "*****"
# Yes this is still accurate. Haihong is working on a KB that we are planning to release to address this. We also will try to fix this on *-main but we haven't yet.
# Yes this is still accurate. Haihong is working on a KB that we are planning to release to address this. We also will try to fix this on *-main but we haven't yet.
# Yes still accurate Haihong working KB planning release address We also try fix *-main n't yet
# yes still accur haihong work kb plan releas address we also tri fix *-main n't yet
# "*****"
# After a  discussion with Dyno, this connect issue has been resolved and Kevin verified this also. Refer to  Regarding mentioned issue inside of VM, it is another issue and Dyno will try to confirm related bugs in main release and he might have a child bug for later update releases.
#
# Hi Sudhir,
#
# Since this connection issue has been resolved , would your team please take some VC regression testing and update this with your result directly ? Refer to similar case at http://bugzilla.eng.vmware.com/show_bug.cgi?id=851719#c50
#
# Btw, I found that Hari and Prasadv in CC list already :)  Thanks in advance!
#
# Best Regards,
# Bo
# After a  discussion with Dyno, this connect issue has been resolved and Kevin verified this also. Refer to  Regarding mentioned issue inside of VM, it is another issue and Dyno will try to confirm related bugs in main release and he might have a child bug for later update releases.
#
# Hi Sudhir,
#
# Since this connection issue has been resolved , would your team please take some VC regression testing and update this with your result directly ? Refer to similar case at http://bugzilla.eng.vmware.com/show_bug.cgi?id=851719#c50
#
# Btw, I found that Hari and Prasadv in CC list already :)  Thanks in advance!
#
# Best Regards,
# Bo
# After discussion Dyno connect issue resolved Kevin verified also Refer Regarding mentioned issue inside VM another issue Dyno try confirm related bugs main release might child bug later update releases Hi Sudhir Since connection issue resolved would team please take VC regression testing update result directly Refer similar case Btw I found Hari Prasadv CC list already Thanks advance Best Regards Bo
# after discuss dyno connect issu resolv kevin verifi also refer regard mention issu insid vm anoth issu dyno tri confirm relat bug main releas might child bug later updat releas hi sudhir sinc connect issu resolv would team pleas take vc regress test updat result direct refer similar case btw i found hari prasadv cc list alreadi thank advanc best regard bo
# "*****"
# Thanks Bo.
#
# we will run the VC regressions and close the PR if no issues are found.
#
# `Sudhir
# Thanks Bo.
#
# we will run the VC regressions and close the PR if no issues are found.
#
# `Sudhir
# Thanks Bo run VC regressions close PR issues found `Sudhir
# thank bo run vc regress close pr issu found `sudhir
# "*****"
# (In reply to comment #80)
# > Based on Update #77  do we need to update this in release notes.
# yes, i think we should.
# yes, i think we should.
# yes think
# yes think
# "*****"
# Completed the regression for USB feature. All tests passed, results uploaded in HPQC at below location.
# Test Lab\Root\MN_Update\VC50U2\VC_UIFVT\Venkatesh\RC2-Client Connected USB
# Test Lab\Root\MN_Update\VC50U2\VC_UIFVT\Venkatesh\RC2-USB30DeviceSupport
#
# Environment Used for Regresson:
# Client OS:windowsxp sp2 32bit
# Guest OS:windows8-64
#
# VC Build:876202
# VC Client:874783
# ESX Build:874202
#
# Regards,
# Venkatesh
# Completed the regression for USB feature. All tests passed, results uploaded in HPQC at below location.
# Test Lab\Root\MN_Update\VC50U2\VC_UIFVT\Venkatesh\RC2-Client Connected USB
# Test Lab\Root\MN_Update\VC50U2\VC_UIFVT\Venkatesh\RC2-USB30DeviceSupport
#
# Environment Used for Regresson:
# Client OS:windowsxp sp2 32bit
# Guest OS:windows8-64
#
# VC Build:876202
# VC Client:874783
# ESX Build:874202
#
# Regards,
# Venkatesh
# Completed regression USB feature All tests passed results uploaded HPQC location Test Lab\Root\MN_Update\VC50U2\VC_UIFVT\Venkatesh\RC2-Client Connected USB Test Lab\Root\MN_Update\VC50U2\VC_UIFVT\Venkatesh\RC2-USB30DeviceSupport Environment Used Regresson Client OS windowsxp sp2 32bit Guest OS windows8-64 VC Build:876202 VC Client:874783 ESX Build:874202 Regards Venkatesh
# complet regress usb featur all test pass result upload hpqc locat test lab\root\mn_update\vc50u2\vc_uifvt\venkatesh\rc2-cli connect usb test lab\root\mn_update\vc50u2\vc_uifvt\venkatesh\rc2-usb30devicesupport environ use regresson client os windowsxp sp2 32bit guest os windows8-64 vc build:876202 vc client:874783 esx build:874202 regard venkatesh
# "*****"
# Tagged with ReleaseNotes Keywords based on Dyno's reply. Refer to comment#84,we might add this as one known issue inside of VM. If we can catch this KB,Refer to comment#81, we might include this info in KB.
#
# Best Regards,
# Bo
# Tagged with ReleaseNotes Keywords based on Dyno's reply. Refer to comment#84,we might add this as one known issue inside of VM. If we can catch this KB,Refer to comment#81, we might include this info in KB.
#
# Best Regards,
# Bo
# Tagged ReleaseNotes Keywords based Dyno 's reply Refer comment might add one known issue inside VM If catch KB Refer comment might include info KB Best Regards Bo
# tag releasenot keyword base dyno 's repli refer comment might add one known issu insid vm if catch kb refer comment might includ info kb best regard bo
# "*****"
# Close this now based on this verification result. Thanks this validation from VMCore team and VC team.
#
# Related KB PR http://bugzilla.eng.vmware.com/show_bug.cgi?id=949813 is talking existing issue, and we might need to add corresponding KB info to this Release Notes once this KB is live. We tagged "ReleaseNotes" in this bug already. Dyno can give its draft on this existing issue.Thanks!
#
# Hi Kevin,
#
# Would you please check this http://bugzilla.eng.vmware.com/show_bug.cgi?id=794394#c29 when you free? Thanks in advance!
#
# Best Regards,
# Bo
# Close this now based on this verification result. Thanks this validation from VMCore team and VC team.
#
# Related KB PR http://bugzilla.eng.vmware.com/show_bug.cgi?id=949813 is talking existing issue, and we might need to add corresponding KB info to this Release Notes once this KB is live. We tagged "ReleaseNotes" in this bug already. Dyno can give its draft on this existing issue.Thanks!
#
# Hi Kevin,
#
# Would you please check this http://bugzilla.eng.vmware.com/show_bug.cgi?id=794394#c29 when you free? Thanks in advance!
#
# Best Regards,
# Bo
# Close based verification result Thanks validation VMCore team VC team Related KB PR talking existing issue might need add corresponding KB info Release Notes KB live We tagged ReleaseNotes bug already Dyno give draft existing issue.Thanks Hi Kevin Would please check free Thanks advance Best Regards Bo
# close base verif result thank valid vmcore team vc team relat kb pr talk exist issu might need add correspond kb info releas note kb live we tag releasenot bug alreadi dyno give draft exist issue.thank hi kevin would pleas check free thank advanc best regard bo
# "*****"
# (In reply to comment #87)
# > Hi Kevin,
# >
# > Would you please check this http://bugzilla.eng.vmware.com/show_bug.cgi?id=794394#c29 when you free? Thanks in advance!
# >
# > Best Regards,
# > Bo
# >
# Hi Bo,
# PR#794394 is view client related. It's not in our coverage.
# Hi Bo,
# PR#794394 is view client related. It's not in our coverage.
# Hi Bo PR view client related It 's coverage
# hi bo pr view client relat it 's coverag
# "*****"
# *** Bug 963093 has been cloned from this bug 794510. ***
# *** Bug 963093 has been cloned from this bug 794510. ***
# Bug cloned bug
# bug clone bug
# "*****"
#
# Cloning for VC 50 U2 Release Notes
#
# Cloning for VC 50 U2 Release Notes
# Cloning VC U2 Release Notes
# clone vc u2 releas note
